# %%
import pandas as pd 
from db import *
from config_poc import *

# %%
pd.set_option('display.max_columns', None)

# %%
sql_stmt = """
select  c.table_name, c.column_name --, c.data_type,  c.*
from information_schema.columns c
where 1=1
--and c.table_catalog like 'faculty-Cornell-CS%'
and c.table_schema = 'main'
and c.table_name in ('t_person', 't_faculty'
)
and c.table_name not like 't1_%'
order by c.table_catalog,c.table_schema,c.table_name, c.ordinal_position
;
"""

# %%
with DBConn() as _conn:
    df = pd.read_sql("select uuid();", _conn)
df
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_18100\1125376890.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select uuid();", _conn)
#                                  uuid()
# 0  c731a0d7-990e-40bd-9217-3661790f351a

# %%
with DBConn() as _conn:
    df = pd.read_sql(sql_stmt, _conn)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_18100\496018617.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_stmt, _conn)

# %%
df
# Out:
#    table_name             column_name
# 0   t_faculty                    name
# 1   t_faculty               job_title
# 2   t_faculty                phd_univ
# 3   t_faculty                phd_year
# 4   t_faculty           research_area
# 5   t_faculty  research_concentration
# 6   t_faculty          research_focus
# 7   t_faculty                     url
# 8   t_faculty                 img_url
# 9   t_faculty                   phone
# 10  t_faculty                   email
# 11  t_faculty              cell_phone
# 12  t_faculty          office_address
# 13  t_faculty              department
# 14  t_faculty                  school
# 15  t_faculty                    note
# 16   t_person                    name
# 17   t_person                     url
# 18   t_person                   email
# 19   t_person              first_name
# 20   t_person                mid_name
# 21   t_person               last_name
# 22   t_person                    note

# %% [raw]
# df.to_records()

# %%
df.to_csv("tab_cols-person-faculty.csv", index=False)

# %%
df_list= df.groupby('table_name')['column_name'].apply(list)

# %%
TABLE_COLUMNS = df_list.to_dict()

# %%
TABLE_COLUMNS
# Out:
# {'t_faculty': ['name',
#   'job_title',
#   'phd_univ',
#   'phd_year',
#   'research_area',
#   'research_concentration',
#   'research_focus',
#   'url',
#   'img_url',
#   'phone',
#   'email',
#   'cell_phone',
#   'office_address',
#   'department',
#   'school',
#   'note'],
#  't_person': ['name',
#   'url',
#   'email',
#   'first_name',
#   'mid_name',
#   'last_name',
#   'note']}

# %%
TABLE_COLUMNS['t_faculty'] + TABLE_COLUMNS['t_person']
# Out:
# ['name',
#  'job_title',
#  'phd_univ',
#  'phd_year',
#  'research_area',
#  'research_concentration',
#  'research_focus',
#  'url',
#  'img_url',
#  'phone',
#  'email',
#  'cell_phone',
#  'office_address',
#  'department',
#  'school',
#  'note',
#  'name',
#  'url',
#  'email',
#  'first_name',
#  'mid_name',
#  'last_name',
#  'note']

# %%
set(TABLE_COLUMNS['t_faculty']).difference(set(TABLE_COLUMNS['t_person']))
# Out:
# {'cell_phone',
#  'department',
#  'img_url',
#  'job_title',
#  'office_address',
#  'phd_univ',
#  'phd_year',
#  'phone',
#  'research_area',
#  'research_concentration',
#  'research_focus',
#  'school'}

# %%
cstr = """
- name
- url
- email
- job_title
- person_type
- phd_univ
- phd_year
- research_area
- research_concentration
- research_focus
- first_name
- mid_name
- last_name
- img_url
- phone
- cell_phone
- office_address
- department
- school
- org
- note"""

cols = [c.replace("-","").strip() for c in cstr.split("\n") if c.strip()]

# %%
cols
# Out:
# ['name',
#  'url',
#  'email',
#  'job_title',
#  'person_type',
#  'phd_univ',
#  'phd_year',
#  'research_area',
#  'research_concentration',
#  'research_focus',
#  'first_name',
#  'mid_name',
#  'last_name',
#  'img_url',
#  'phone',
#  'cell_phone',
#  'office_address',
#  'department',
#  'school',
#  'org',
#  'note']

# %%
(set(TABLE_COLUMNS['t_faculty']).union(set(cols))).difference(set(TABLE_COLUMNS['t_person']))
# Out:
# {'cell_phone',
#  'department',
#  'img_url',
#  'job_title',
#  'office_address',
#  'org',
#  'person_type',
#  'phd_univ',
#  'phd_year',
#  'phone',
#  'research_area',
#  'research_concentration',
#  'research_focus',
#  'school'}

# %%
for c in ['id','ts',
 'job_title',
 'person_type',
 'phd_univ',
 'phd_year',
 'research_area',
 'research_concentration',
 'research_focus',
 'img_url',
 'phone',
 'cell_phone',
 'office_address',
 'department',
 'school', 
 'org',
]:
    
    print(f"alter table t_person add column {c} text;")
# Out:
# alter table t_person add column id text;
# alter table t_person add column ts text;
# alter table t_person add column job_title text;
# alter table t_person add column person_type text;
# alter table t_person add column phd_univ text;
# alter table t_person add column phd_year text;
# alter table t_person add column research_area text;
# alter table t_person add column research_concentration text;
# alter table t_person add column research_focus text;
# alter table t_person add column img_url text;
# alter table t_person add column phone text;
# alter table t_person add column cell_phone text;
# alter table t_person add column office_address text;
# alter table t_person add column department text;
# alter table t_person add column school text;
# alter table t_person add column org text;

# %%
col_lst = ",".join(["id","ts","person_type"] + TABLE_COLUMNS['t_faculty'])
col_lst
# Out:
# 'id,ts,person_type,name,job_title,phd_univ,phd_year,research_area,research_concentration,research_focus,url,img_url,phone,email,cell_phone,office_address,department,school,note'

# %%
col_lst2 = ",".join(TABLE_COLUMNS['t_faculty'])
col_lst2
# Out:
# 'name,job_title,phd_univ,phd_year,research_area,research_concentration,research_focus,url,img_url,phone,email,cell_phone,office_address,department,school,note'

# %%
insert_sql = f"""
insert into t_person ({col_lst})
select uuid(),now(),'faculty',{col_lst2}  
from t_faculty
--where name = 'Abe Davis'
;
"""

print(insert_sql)
# Out:
# insert into t_person (id,ts,person_type,name,job_title,phd_univ,phd_year,research_area,research_concentration,research_focus,url,img_url,phone,email,cell_phone,office_address,department,school,note)
# select uuid(),now(),'faculty',name,job_title,phd_univ,phd_year,research_area,research_concentration,research_focus,url,img_url,phone,email,cell_phone,office_address,department,school,note
# from t_faculty
# --where name = 'Abe Davis'
# ;

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df = pd.read_sql("select * from t_person;", _conn)
df
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_18100\3297502769.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("select * from t_person;", _conn)
#                     name                                      url  \
# 0           Yuchong Geng          https://yuchong-geng.github.io/
# 1        Faraz Farahvash    http://networks.ece.cornell.edu/faraz
# 2    Mohamed Abdelfattah                 https://www.mohsaied.com
# 3        Jayadev Acharya  https://people.ece.cornell.edu/acharya/
# 4         Rachit Agarwal     http://www.cs.cornell.edu/~ragarwal/
# ..                   ...                                      ...
# 119     Christina Lee Yu  https://people.orie.cornell.edu/cleeyu/
# 120           Haiyuan Yu                    https://www.yulab.org
# 121          Ramin Zabih           http://www.cs.cornell.edu/~rdz
# 122          Cheng Zhang                   http://www.czhang.org/
# 123          Zhiru Zhang      http://www.csl.cornell.edu/~zhiruz/
#
#                  email first_name mid_name  last_name  note  \
# 0    yg534@cornell.edu    Yuchong     None       Geng  None
# 1    ff227@cornell.edu      Faraz     None  Farahvash  None
# 2                            None     None       None  None
# 3                            None     None       None  None
# 4                            None     None       None  None
# ..                 ...        ...      ...        ...   ...
# 119                          None     None       None  None
# 120                          None     None       None  None
# 121                          None     None       None  None
# 122                          None     None       None  None
# 123                          None     None       None  None
#
#                                        id                          ts  \
# 0                       yg534@cornell.edu                        None
# 1                       ff227@cornell.edu                        None
# 2    409a467e-159e-411e-aedf-206e0ce0d71e  2023-04-23 14:48:37.555-04
# 3    23605352-f553-4289-86fd-e967a3ae693b  2023-04-23 14:48:37.555-04
# 4    edf90ce7-67ff-474d-8b17-47f6e43fa5c2  2023-04-23 14:48:37.555-04
# ..                                    ...                         ...
# 119  8341ddc8-421a-46ef-bb12-1e58d54aee05  2023-04-23 14:48:37.555-04
# 120  9bd309b1-8bea-4045-b7e6-e91713bc5c2e  2023-04-23 14:48:37.555-04
# 121  7fc156ee-f1b0-4cfc-b5fc-00a45c74bd3f  2023-04-23 14:48:37.555-04
# 122  35b999c8-0033-4364-bc92-3abeb1dad5f0  2023-04-23 14:48:37.555-04
# 123  57fb0751-7fa1-4b86-9251-abb028e6080a  2023-04-23 14:48:37.555-04
#
#                 job_title person_type                        phd_univ  \
# 0                    None        None                            None
# 1                    None        None                            None
# 2     Assistant Professor     faculty                    Univ Toronto
# 3     Assistant Professor     faculty       Univ California San Diego
# 4    Associate Professor      faculty  Univ Illinois Urbana-Champaign
# ..                    ...         ...                             ...
# 119   Assistant Professor     faculty                             MIT
# 120             Professor     faculty                            Yale
# 121             Professor     faculty                   Stanford Univ
# 122   Assistant Professor     faculty    Georgia Institute Technology
# 123   Assistant Professor     faculty              Univ California LA
#
#     phd_year                                 research_area  \
# 0       None                                          None
# 1       None                                          None
# 2       2016     Artificial Intelligence, Machine Learning
# 3       2014  Artificial Intelligence, Theory of Computing
# 4       2013   Systems and Networking, Theory of Computing
# ..       ...                                           ...
# 119                                    Theory of Computing
# 120     2005                         Computational Biology
# 121     1994                     Human Interaction, Vision
# 122     2018                       Artificial Intelligence
# 123     2007                        Systems and Networking
#
#                              research_concentration  \
# 0                                              None
# 1                                              None
# 2                           Artificial Intelligence
# 3    Artificial Intelligence, Theory of Computation
# 4                    Systems, Theory of Computation
# ..                                              ...
# 119                           Theory of Computation
# 120           Scientific Computing and Applications
# 121  Artificial Intelligence, Theory of Computation
# 122                                         Systems
# 123                                         Systems
#
#                                         research_focus  \
# 0                                                 None
# 1                                                 None
# 2
# 3    Information theory, machine learning, and algo...
# 4    Distributed systems, systems for big data anal...
# ..                                                 ...
# 119  Theory of Computing, Artificial Intelligence (...
# 120  Biomedical systems biology, machine learning, ...
# 121  Computer vision and its applications, especial...
# 122  Ubiquitous Computing, Wearable Computing, Huma...
# 123  Computer-aided design methodologies, optimizat...
#
#                                                img_url phone cell_phone  \
# 0                                                 None  None       None
# 1                                                 None  None       None
# 2    https://www.cs.cornell.edu/sites/default/files...
# 3    https://www.cs.cornell.edu/sites/default/files...
# 4    https://www.cs.cornell.edu/sites/default/files...
# ..                                                 ...   ...        ...
# 119  https://www.cs.cornell.edu/sites/default/files...
# 120  https://www.cs.cornell.edu/sites/default/files...
# 121  https://www.cs.cornell.edu/sites/default/files...
# 122  https://www.cs.cornell.edu/sites/default/files...
# 123  https://www.cs.cornell.edu/sites/default/files...
#
#     office_address                                         department school  \
# 0             None                                               None   None
# 1             None                                               None   None
# 2                   Electrical and Computer Engineering, Cornell T...
# 3                   Electrical and Computer Engineering, CS Field ...
# 4                                   Computer Science, CS Field Member
# ..             ...                                                ...    ...
# 119                                             ORIE, CS Field Member
# 120                 Biological Statistics & Computational Biology,...
# 121                   Computer Science, Cornell Tech, CS Field Member
# 122                              Information Science, CS Field Member
# 123                 Electrical and Computer Engineering, CS Field ...
#
#       org
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# ..    ...
# 119  None
# 120  None
# 121  None
# 122  None
# 123  None
#
# [124 rows x 23 columns]

# %%
# delete
with DBConn() as _conn:
    _conn.execute("delete from t_person where name = 'Abe Davis';")
    _conn.commit()
