# %%
import pandas as pd 
from app_config import COLUMN_PROPS
import json
from uuid import uuid4
from datetime import datetime

# %%
from app_helper import (
        DBConn, )

# %%
COLUMN_PROPS
# Out:
# {'g_entity': {'name': {'is_system_col': False,
#    'is_user_key': True,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input',
#    'label_text': 'Name'},
#   'url': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': True,
#    'form_column': 'COL_1-2',
#    'widget_type': 'text_input',
#    'label_text': 'URL'},
#   'tags': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'text_input'},
#   'entity_type': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'selectbox'},
#   'note': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'text_area',
#    'label_text': 'Note'},
#   'ref_tab': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-1',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Table'},
#   'ref_key': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-2',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Column'},
#   'ref_val': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-3',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Value'},
#   'id': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-97',
#    'widget_type': 'text_input',
#    'label_text': 'ID'},
#   'ts': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-98',
#    'widget_type': 'text_input',
#    'label_text': 'Timestamp'},
#   'uid': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-99',
#    'widget_type': 'text_input',
#    'label_text': 'UID'}},
#  'g_person': {'name': {'is_system_col': False,
#    'is_user_key': True,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input',
#    'label_text': 'Name'},
#   'url': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': True,
#    'form_column': 'COL_1-2',
#    'widget_type': 'text_input',
#    'label_text': 'URL'},
#   'research_area': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'text_input',
#    'label_text': 'Research Area'},
#   'job_title': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-4',
#    'widget_type': 'text_input'},
#   'tags': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-5',
#    'widget_type': 'text_input'},
#   'department': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-6',
#    'widget_type': 'text_input'},
#   'email': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-1',
#    'widget_type': 'text_input',
#    'label_text': 'Email'},
#   'cell_phone': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'text_input',
#    'label_text': 'Cell'},
#   'office_address': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'text_input'},
#   'note': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-4',
#    'widget_type': 'text_area',
#    'label_text': 'Note'},
#   'person_type': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-2',
#    'widget_type': 'selectbox',
#    'label_text': 'Person Type'},
#   'award': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-3',
#    'widget_type': 'text_input'},
#   'org': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-4',
#    'widget_type': 'text_input'},
#   'phd_univ': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-5',
#    'widget_type': 'text_input'},
#   'phd_year': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-6',
#    'widget_type': 'text_input'},
#   'id': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-97',
#    'widget_type': 'text_input',
#    'label_text': 'ID'},
#   'ts': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-98',
#    'widget_type': 'text_input',
#    'label_text': 'Timestamp'},
#   'uid': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-99',
#    'widget_type': 'text_input',
#    'label_text': 'UID'}},
#  'g_note': {'name': {'is_system_col': False,
#    'is_user_key': True,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input'},
#   'url': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': True,
#    'form_column': 'COL_1-2',
#    'widget_type': 'text_input',
#    'label_text': 'URL'},
#   'tags': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'text_input'},
#   'note_type': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'selectbox'},
#   'note': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'text_area'},
#   'ref_tab': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-1',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Table'},
#   'ref_key': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-2',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Column'},
#   'ref_val': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-3',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Value'},
#   'id': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-97',
#    'widget_type': 'text_input',
#    'label_text': 'ID'},
#   'ts': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-98',
#    'widget_type': 'text_input',
#    'label_text': 'Timestamp'},
#   'uid': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-99',
#    'widget_type': 'text_input',
#    'label_text': 'UID'}},
#  'g_org': {'name': {'is_system_col': False,
#    'is_user_key': True,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input'},
#   'url': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': True,
#    'form_column': 'COL_1-2',
#    'widget_type': 'text_input',
#    'label_text': 'URL'},
#   'tags': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'text_input'},
#   'org_type': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'selectbox'},
#   'note': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'text_area'},
#   'ref_tab': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-1',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Table'},
#   'ref_key': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-2',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Column'},
#   'ref_val': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-3',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Value'},
#   'id': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-97',
#    'widget_type': 'text_input',
#    'label_text': 'ID'},
#   'ts': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-98',
#    'widget_type': 'text_input',
#    'label_text': 'Timestamp'},
#   'uid': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-99',
#    'widget_type': 'text_input',
#    'label_text': 'UID'}},
#  'g_project': {'name': {'is_system_col': False,
#    'is_user_key': True,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input'},
#   'url': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': True,
#    'form_column': 'COL_1-2',
#    'widget_type': 'text_input',
#    'label_text': 'URL'},
#   'tags': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'text_input'},
#   'project_type': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'selectbox'},
#   'note': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'text_area'},
#   'ref_tab': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-1',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Table'},
#   'ref_key': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-2',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Column'},
#   'ref_val': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-3',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Value'},
#   'id': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-97',
#    'widget_type': 'text_input',
#    'label_text': 'ID'},
#   'ts': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-98',
#    'widget_type': 'text_input',
#    'label_text': 'Timestamp'},
#   'uid': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-99',
#    'widget_type': 'text_input',
#    'label_text': 'UID'}},
#  'g_work': {'name': {'is_system_col': False,
#    'is_user_key': True,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input'},
#   'url': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': True,
#    'form_column': 'COL_1-2',
#    'widget_type': 'text_input'},
#   'summary': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'text_area'},
#   'authors': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-1',
#    'widget_type': 'text_input'},
#   'tags': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'text_input'},
#   'note': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'text_area'},
#   'work_type': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-2',
#    'widget_type': 'selectbox'},
#   'award': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-3',
#    'widget_type': 'text_input'},
#   'id': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-97',
#    'widget_type': 'text_input',
#    'label_text': 'ID'},
#   'ts': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-98',
#    'widget_type': 'text_input',
#    'label_text': 'Timestamp'},
#   'uid': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-99',
#    'widget_type': 'text_input',
#    'label_text': 'UID'}},
#  'g_task': {'name': {'is_system_col': False,
#    'is_user_key': True,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input'},
#   'url': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': True,
#    'form_column': 'COL_1-2',
#    'widget_type': 'text_input'},
#   'priority': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'selectbox'},
#   'note': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-4',
#    'widget_type': 'text_area'},
#   'tags': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-5',
#    'widget_type': 'text_input'},
#   'task_status': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-1',
#    'widget_type': 'selectbox'},
#   'due_date': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'date_input'},
#   'alert_date': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'date_input'},
#   'alert_time': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-4',
#    'widget_type': 'time_input'},
#   'alert_to': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-5',
#    'widget_type': 'text_input',
#    'label_text': 'Alert To (cell or email)'},
#   'alert_msg': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_2-6',
#    'widget_type': 'text_input'},
#   'ref_tab': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-2',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Table'},
#   'ref_key': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-3',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Column'},
#   'ref_val': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-4',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Value'},
#   'done_date': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_3-5',
#    'widget_type': 'date_input',
#    'label_text': 'Completion Date'},
#   'id': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': True,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-97',
#    'widget_type': 'text_input',
#    'label_text': 'ID'},
#   'ts': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-98',
#    'widget_type': 'text_input',
#    'label_text': 'Timestamp'},
#   'uid': {'is_system_col': True,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_3-99',
#    'widget_type': 'text_input',
#    'label_text': 'UID'}},
#  'g_relation': {'rel_type': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': True,
#    'is_editable': True,
#    'is_clickable': False,
#    'form_column': 'COL_1-1',
#    'widget_type': 'text_input'},
#   'ref_key': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': False,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_1-2',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Column'},
#   'ref_val': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': False,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_1-3',
#    'widget_type': 'selectbox',
#    'label_text': 'Ref Value'},
#   'ref_key_sub': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': False,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_2-2',
#    'widget_type': 'text_input'},
#   'ref_val_sub': {'is_system_col': False,
#    'is_user_key': False,
#    'is_required': False,
#    'is_visible': False,
#    'is_editable': False,
#    'is_clickable': False,
#    'form_column': 'COL_2-3',
#    'widget_type': 'text_input'}}}

# %%
tmp = """
id
ts
uid
table_name
col_name
	is_system_col 
	is_user_key 
	is_required 
	is_visible 
	is_editable 
	is_clickable 
	form_column 
	widget_type 
	label_text 
	kwargs
"""
attribs = [i.strip()  for i in tmp.split("\n") if i.strip()]

attribs
# Out:
# ['id',
#  'ts',
#  'uid',
#  'table_name',
#  'col_name',
#  'is_system_col',
#  'is_user_key',
#  'is_required',
#  'is_visible',
#  'is_editable',
#  'is_clickable',
#  'form_column',
#  'widget_type',
#  'label_text',
#  'kwargs']

# %% [raw]
# attribs = ['id',
#  'ts',
#  'uid',
#  'table_name',
#  'col_name',
#  'is_system_col',
#  'is_user_key',
#  'is_required',
#  'is_visible',
#  'is_editable',
#  'is_clickable',
#  'form_column',
#  'widget_type',
#  'label_text',
#  'kwargs']

# %%
_ts = str(datetime.now())
rows = []
for table_name in COLUMN_PROPS.keys():
    for col_name in COLUMN_PROPS[table_name].keys():
        row = []
        for att in attribs:
            if att == "id":
                val = str(uuid4())
            elif att == "ts":
                val = _ts
            elif att == "uid":
                val = "0"
            elif att == "table_name":
                val = table_name
            elif att == "col_name":
                val = col_name
            else:
                val = COLUMN_PROPS[table_name][col_name].get(att, "")
            row.append(val)
        rows.append(row)

# %%
rows
# Out:
# [['29aeab4c-eef3-4598-9fa2-a01383205887',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'name',
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   'Name',
#   ''],
#  ['e10f5f36-03fc-4f7d-be7a-51057c019841',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'url',
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   'COL_1-2',
#   'text_input',
#   'URL',
#   ''],
#  ['c66fb52d-c62d-4091-8dce-825cfc707153',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'tags',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-3',
#   'text_input',
#   '',
#   ''],
#  ['79edf873-eb78-487c-8cab-7862af99514f',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'entity_type',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-2',
#   'selectbox',
#   '',
#   ''],
#  ['00c19748-314d-4ea3-89ae-0cd804a474f3',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'note',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-3',
#   'text_area',
#   'Note',
#   ''],
#  ['1868896e-e7d3-4b19-8ec4-489ff29e93cc',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'ref_tab',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-1',
#   'selectbox',
#   'Ref Table',
#   ''],
#  ['71ef4c6c-6cdf-45d8-b1c1-725aab5071e3',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'ref_key',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-2',
#   'selectbox',
#   'Ref Column',
#   ''],
#  ['55c4d68b-d27d-4d06-8cec-d96daae7d510',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'ref_val',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-3',
#   'selectbox',
#   'Ref Value',
#   ''],
#  ['a41e4a78-c4e2-4a54-9069-174939bdd39e',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'id',
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   'COL_3-97',
#   'text_input',
#   'ID',
#   ''],
#  ['07b34893-e254-40b7-bba6-c279291f07cf',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'ts',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-98',
#   'text_input',
#   'Timestamp',
#   ''],
#  ['0d5d3993-1e60-46c2-8d32-620066f1b15b',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_entity',
#   'uid',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-99',
#   'text_input',
#   'UID',
#   ''],
#  ['fa32c9da-17fd-4a7f-8feb-b535b0a40ed4',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'name',
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   'Name',
#   ''],
#  ['556f13ce-c942-469a-8f4c-ec5dc0a1b57a',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'url',
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   'COL_1-2',
#   'text_input',
#   'URL',
#   ''],
#  ['8f59a040-0aa1-440f-a7ab-12489ce258b4',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'research_area',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-3',
#   'text_input',
#   'Research Area',
#   ''],
#  ['b25eba5d-ebc5-4449-b2de-f92393a0348d',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'job_title',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-4',
#   'text_input',
#   '',
#   ''],
#  ['fd6ba46e-f967-400a-be72-2dc098185f4b',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'tags',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-5',
#   'text_input',
#   '',
#   ''],
#  ['95af8bfc-72d7-4c17-9351-1d95318be039',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'department',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-6',
#   'text_input',
#   '',
#   ''],
#  ['d0a4b8fd-f7b8-4306-80eb-086ddb6611b1',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'email',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-1',
#   'text_input',
#   'Email',
#   ''],
#  ['f1120b57-c996-4a13-b8e9-ac8aeaa54bbf',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'cell_phone',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-2',
#   'text_input',
#   'Cell',
#   ''],
#  ['39dc03ab-1e95-4e7f-bc87-4b8a470b5d8f',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'office_address',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-3',
#   'text_input',
#   '',
#   ''],
#  ['73915fe3-8489-4eb1-8b54-25bda12f4a88',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'note',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-4',
#   'text_area',
#   'Note',
#   ''],
#  ['3019cb46-e2d1-4019-b1e8-15d408ce7441',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'person_type',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-2',
#   'selectbox',
#   'Person Type',
#   ''],
#  ['55ea5912-9b24-4b8d-ae1f-e45b8c16f43b',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'award',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-3',
#   'text_input',
#   '',
#   ''],
#  ['6a99919c-50ce-48c1-a668-1e63b986ebeb',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'org',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-4',
#   'text_input',
#   '',
#   ''],
#  ['3db27d93-4b1b-4cd0-9a41-7b256586bd7a',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'phd_univ',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-5',
#   'text_input',
#   '',
#   ''],
#  ['eb566395-4eb8-4df7-a1bc-4c200f1a4662',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'phd_year',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-6',
#   'text_input',
#   '',
#   ''],
#  ['773481a4-2a83-4dcb-af11-e3452d8fc59e',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'id',
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   'COL_3-97',
#   'text_input',
#   'ID',
#   ''],
#  ['a8e92f5e-1aae-4646-be84-5ce09d48ddce',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'ts',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-98',
#   'text_input',
#   'Timestamp',
#   ''],
#  ['b40b833f-2b99-4746-9367-28cf771ab04e',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_person',
#   'uid',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-99',
#   'text_input',
#   'UID',
#   ''],
#  ['4e63d047-240a-458a-a919-199aa8ac04e6',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'name',
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   '',
#   ''],
#  ['843128ab-806a-481b-957b-825002d01a7f',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'url',
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   'COL_1-2',
#   'text_input',
#   'URL',
#   ''],
#  ['951b56dd-b602-4e07-bfb9-58b0bc6a8156',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'tags',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-3',
#   'text_input',
#   '',
#   ''],
#  ['a303ab2a-4da2-4e08-bd02-fda36cd8eb14',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'note_type',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-2',
#   'selectbox',
#   '',
#   ''],
#  ['3b8d0679-cd1e-4377-a9c8-366c3c3a144c',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'note',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-3',
#   'text_area',
#   '',
#   ''],
#  ['153e63a7-012f-4d93-819f-20e0a552f7e2',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'ref_tab',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-1',
#   'selectbox',
#   'Ref Table',
#   ''],
#  ['6b192a92-7901-46c7-8a51-19cc34453115',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'ref_key',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-2',
#   'selectbox',
#   'Ref Column',
#   ''],
#  ['4ac1ab88-a036-42e3-b262-930d96f46bc2',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'ref_val',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-3',
#   'selectbox',
#   'Ref Value',
#   ''],
#  ['b8279503-e9fc-40a5-827d-fd183282b602',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'id',
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   'COL_3-97',
#   'text_input',
#   'ID',
#   ''],
#  ['4ffc9902-d193-4ac0-a0c5-7ce8706c8cb2',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'ts',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-98',
#   'text_input',
#   'Timestamp',
#   ''],
#  ['72c64b29-b0be-4491-b67a-d0533c0293ef',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_note',
#   'uid',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-99',
#   'text_input',
#   'UID',
#   ''],
#  ['a3c29528-bf88-4b8b-bc70-c4b0f43a9ad7',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'name',
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   '',
#   ''],
#  ['d67a57d1-8fe9-4e4d-ad36-7f80a89651ca',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'url',
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   'COL_1-2',
#   'text_input',
#   'URL',
#   ''],
#  ['c2f3fce6-51d9-4817-b401-eef617acc10c',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'tags',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-3',
#   'text_input',
#   '',
#   ''],
#  ['606d06c3-c4ef-47c3-9313-85c01223afe8',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'org_type',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-2',
#   'selectbox',
#   '',
#   ''],
#  ['96ede44b-3d20-426c-bb3f-05e72722735b',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'note',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-3',
#   'text_area',
#   '',
#   ''],
#  ['94e9d2d3-3d65-441e-be61-e1b33781b55a',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'ref_tab',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-1',
#   'selectbox',
#   'Ref Table',
#   ''],
#  ['623ce9df-ab21-47b2-840e-3b04ab1d81cc',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'ref_key',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-2',
#   'selectbox',
#   'Ref Column',
#   ''],
#  ['5482dadd-99d1-4ab1-bcdc-1ba9c12b8b04',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'ref_val',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-3',
#   'selectbox',
#   'Ref Value',
#   ''],
#  ['577ebc26-c7b3-4bbb-91ed-7b2499416911',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'id',
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   'COL_3-97',
#   'text_input',
#   'ID',
#   ''],
#  ['9337a68b-c783-4711-9d60-2205fba593ec',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'ts',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-98',
#   'text_input',
#   'Timestamp',
#   ''],
#  ['3f9df4bc-6f81-4943-b791-8fbf46744a18',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_org',
#   'uid',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-99',
#   'text_input',
#   'UID',
#   ''],
#  ['36a2645e-e894-4041-ab8e-991292d9ba70',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'name',
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   '',
#   ''],
#  ['8b2395d2-d2eb-464c-aad4-274f72ec6a2f',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'url',
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   'COL_1-2',
#   'text_input',
#   'URL',
#   ''],
#  ['dfd5c7e1-97b7-4091-b29e-99cda311a38b',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'tags',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-3',
#   'text_input',
#   '',
#   ''],
#  ['749aff62-b7ec-4a7b-90c7-3db39865654d',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'project_type',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-2',
#   'selectbox',
#   '',
#   ''],
#  ['fb290dec-9355-4b48-a0ff-628a408c17f0',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'note',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-3',
#   'text_area',
#   '',
#   ''],
#  ['0ea1e098-c499-4825-a32a-da3d98cf99b3',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'ref_tab',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-1',
#   'selectbox',
#   'Ref Table',
#   ''],
#  ['7bdcb605-4b01-48c1-ba4f-73d639cb1644',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'ref_key',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-2',
#   'selectbox',
#   'Ref Column',
#   ''],
#  ['a15aeebc-7568-4600-bd55-9aca0e4b9e2c',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'ref_val',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-3',
#   'selectbox',
#   'Ref Value',
#   ''],
#  ['b46cb32c-e07a-48cc-bc8a-79fda283cd21',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'id',
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   'COL_3-97',
#   'text_input',
#   'ID',
#   ''],
#  ['48c89508-a3e0-47ad-b84c-cd533b46a45d',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'ts',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-98',
#   'text_input',
#   'Timestamp',
#   ''],
#  ['478fdd66-1ac6-4133-9b31-f8a955075351',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_project',
#   'uid',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-99',
#   'text_input',
#   'UID',
#   ''],
#  ['57f98b69-f945-4c2c-95e5-1e3d5be4049a',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'name',
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   '',
#   ''],
#  ['6c0f07ea-34b5-488f-be66-11797d626275',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'url',
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   'COL_1-2',
#   'text_input',
#   '',
#   ''],
#  ['ad85bd2c-b94b-4d91-b42f-1afe87c7f77b',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'summary',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-3',
#   'text_area',
#   '',
#   ''],
#  ['075cdecf-d2f2-4e0f-8655-bbc694fe879b',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'authors',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-1',
#   'text_input',
#   '',
#   ''],
#  ['aa7dcc46-977b-45e3-b950-7ab0e95f9bb1',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'tags',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-2',
#   'text_input',
#   '',
#   ''],
#  ['e9cb4399-8c54-4dc9-a12e-78d017f15598',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'note',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-3',
#   'text_area',
#   '',
#   ''],
#  ['8813c708-4590-456e-bec4-7ba9620acace',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'work_type',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-2',
#   'selectbox',
#   '',
#   ''],
#  ['2a57644f-230d-4295-83da-af87652a5d0c',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'award',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-3',
#   'text_input',
#   '',
#   ''],
#  ['a96c504c-7bbc-488b-a547-7962870378b5',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'id',
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   'COL_3-97',
#   'text_input',
#   'ID',
#   ''],
#  ['5c0d2172-5b77-4479-88b4-4fd73ecb14e2',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'ts',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-98',
#   'text_input',
#   'Timestamp',
#   ''],
#  ['f464eed1-d05e-4677-990b-e3ede643ee95',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_work',
#   'uid',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-99',
#   'text_input',
#   'UID',
#   ''],
#  ['87776ddd-74cc-431e-8771-657d5d451959',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'name',
#   False,
#   True,
#   True,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   '',
#   ''],
#  ['03143114-def0-43e0-8c0e-c4c0d3b23d2d',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'url',
#   False,
#   False,
#   False,
#   True,
#   True,
#   True,
#   'COL_1-2',
#   'text_input',
#   '',
#   ''],
#  ['4ad1a143-735e-4967-aa90-d52f52fa6c86',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'priority',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-3',
#   'selectbox',
#   '',
#   ''],
#  ['bdc4fb28-9794-4b08-a70e-6c2d72e5f5e9',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'note',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-4',
#   'text_area',
#   '',
#   ''],
#  ['af6a33b9-a68a-4af0-b423-19800ec269c3',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'tags',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-5',
#   'text_input',
#   '',
#   ''],
#  ['84db726b-49d3-482f-886f-75891d6a0aca',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'task_status',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-1',
#   'selectbox',
#   '',
#   ''],
#  ['f688cc66-0025-4df5-8a6d-e3dfdc102398',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'due_date',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-2',
#   'date_input',
#   '',
#   ''],
#  ['56f74bf7-9c5b-4e30-829e-3b24db999f8d',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'alert_date',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-3',
#   'date_input',
#   '',
#   ''],
#  ['29c89722-d1ac-480f-b281-9af8f7d9e188',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'alert_time',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-4',
#   'time_input',
#   '',
#   ''],
#  ['0a6ace5a-bf2e-47e7-9ad2-f3bcf6532f95',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'alert_to',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-5',
#   'text_input',
#   'Alert To (cell or email)',
#   ''],
#  ['03659981-fbe1-4c17-b546-767d1af1543e',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'alert_msg',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_2-6',
#   'text_input',
#   '',
#   ''],
#  ['4fbd1683-ad37-4c53-a23a-bae112f43522',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'ref_tab',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-2',
#   'selectbox',
#   'Ref Table',
#   ''],
#  ['076def28-632d-4239-bf54-73d182be9c22',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'ref_key',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-3',
#   'selectbox',
#   'Ref Column',
#   ''],
#  ['f8717418-d546-47a4-9672-0618513acde7',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'ref_val',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-4',
#   'selectbox',
#   'Ref Value',
#   ''],
#  ['7aad1d31-1047-403f-be0a-4411bd96cf52',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'done_date',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_3-5',
#   'date_input',
#   'Completion Date',
#   ''],
#  ['c4dd590a-577f-4e26-8f78-94c9c14d9a4a',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'id',
#   True,
#   False,
#   True,
#   True,
#   False,
#   False,
#   'COL_3-97',
#   'text_input',
#   'ID',
#   ''],
#  ['d60a7604-f097-4668-b917-5eaaa5c5ac41',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'ts',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-98',
#   'text_input',
#   'Timestamp',
#   ''],
#  ['dfba9a3a-b5e1-4269-9fab-ca64d39151ac',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_task',
#   'uid',
#   True,
#   False,
#   False,
#   True,
#   False,
#   False,
#   'COL_3-99',
#   'text_input',
#   'UID',
#   ''],
#  ['e0d19d5e-95e6-4c9d-a7d1-9aef70bee5ab',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_relation',
#   'rel_type',
#   False,
#   False,
#   False,
#   True,
#   True,
#   False,
#   'COL_1-1',
#   'text_input',
#   '',
#   ''],
#  ['73b9feae-b3c3-4bf9-bd35-f6dedcf296e8',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_relation',
#   'ref_key',
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   'COL_1-2',
#   'selectbox',
#   'Ref Column',
#   ''],
#  ['c066dac6-961e-4de4-a3bd-ab39a657eea4',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_relation',
#   'ref_val',
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   'COL_1-3',
#   'selectbox',
#   'Ref Value',
#   ''],
#  ['3df924bf-5471-41f8-be9f-05fcc129cf96',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_relation',
#   'ref_key_sub',
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   'COL_2-2',
#   'text_input',
#   '',
#   ''],
#  ['6c6cf649-55a9-4179-aa78-d88bc34d7a2f',
#   '2023-05-29 23:50:11.056294',
#   '0',
#   'g_relation',
#   'ref_val_sub',
#   False,
#   False,
#   False,
#   False,
#   False,
#   False,
#   'COL_2-3',
#   'text_input',
#   '',
#   '']]

# %%
col_list = str(attribs).replace("[", "(").replace("]", ")").replace("'", "")
col_list
# Out:
# '(id, ts, uid, table_name, col_name, is_system_col, is_user_key, is_required, is_visible, is_editable, is_clickable, form_column, widget_type, label_text, kwargs)'

# %%
val_list = []
for row in rows:
    val_list.append(str(row).replace("[", "(").replace("]", ")"))

# %%
val_list[0]
# Out:
# "('29aeab4c-eef3-4598-9fa2-a01383205887', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'name', False, True, True, True, True, False, 'COL_1-1', 'text_input', 'Name', '')"

# %%
sql_stmt = f"""
insert into g_column_props {col_list}
values {", ".join(val_list)}
;
"""

# %%
print(sql_stmt)
# Out:
# insert into g_column_props (id, ts, uid, table_name, col_name, is_system_col, is_user_key, is_required, is_visible, is_editable, is_clickable, form_column, widget_type, label_text, kwargs)
# values ('29aeab4c-eef3-4598-9fa2-a01383205887', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'name', False, True, True, True, True, False, 'COL_1-1', 'text_input', 'Name', ''), ('e10f5f36-03fc-4f7d-be7a-51057c019841', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'url', False, False, False, True, True, True, 'COL_1-2', 'text_input', 'URL', ''), ('c66fb52d-c62d-4091-8dce-825cfc707153', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'tags', False, False, False, True, True, False, 'COL_1-3', 'text_input', '', ''), ('79edf873-eb78-487c-8cab-7862af99514f', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'entity_type', False, False, False, True, True, False, 'COL_2-2', 'selectbox', '', ''), ('00c19748-314d-4ea3-89ae-0cd804a474f3', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'note', False, False, False, True, True, False, 'COL_2-3', 'text_area', 'Note', ''), ('1868896e-e7d3-4b19-8ec4-489ff29e93cc', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'ref_tab', False, False, False, True, True, False, 'COL_3-1', 'selectbox', 'Ref Table', ''), ('71ef4c6c-6cdf-45d8-b1c1-725aab5071e3', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'ref_key', False, False, False, True, True, False, 'COL_3-2', 'selectbox', 'Ref Column', ''), ('55c4d68b-d27d-4d06-8cec-d96daae7d510', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'ref_val', False, False, False, True, True, False, 'COL_3-3', 'selectbox', 'Ref Value', ''), ('a41e4a78-c4e2-4a54-9069-174939bdd39e', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'id', True, False, True, True, False, False, 'COL_3-97', 'text_input', 'ID', ''), ('07b34893-e254-40b7-bba6-c279291f07cf', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'ts', True, False, False, True, False, False, 'COL_3-98', 'text_input', 'Timestamp', ''), ('0d5d3993-1e60-46c2-8d32-620066f1b15b', '2023-05-29 23:50:11.056294', '0', 'g_entity', 'uid', True, False, False, True, False, False, 'COL_3-99', 'text_input', 'UID', ''), ('fa32c9da-17fd-4a7f-8feb-b535b0a40ed4', '2023-05-29 23:50:11.056294', '0', 'g_person', 'name', False, True, True, True, True, False, 'COL_1-1', 'text_input', 'Name', ''), ('556f13ce-c942-469a-8f4c-ec5dc0a1b57a', '2023-05-29 23:50:11.056294', '0', 'g_person', 'url', False, False, False, True, True, True, 'COL_1-2', 'text_input', 'URL', ''), ('8f59a040-0aa1-440f-a7ab-12489ce258b4', '2023-05-29 23:50:11.056294', '0', 'g_person', 'research_area', False, False, False, True, True, False, 'COL_1-3', 'text_input', 'Research Area', ''), ('b25eba5d-ebc5-4449-b2de-f92393a0348d', '2023-05-29 23:50:11.056294', '0', 'g_person', 'job_title', False, False, False, True, True, False, 'COL_1-4', 'text_input', '', ''), ('fd6ba46e-f967-400a-be72-2dc098185f4b', '2023-05-29 23:50:11.056294', '0', 'g_person', 'tags', False, False, False, True, True, False, 'COL_1-5', 'text_input', '', ''), ('95af8bfc-72d7-4c17-9351-1d95318be039', '2023-05-29 23:50:11.056294', '0', 'g_person', 'department', False, False, False, True, True, False, 'COL_1-6', 'text_input', '', ''), ('d0a4b8fd-f7b8-4306-80eb-086ddb6611b1', '2023-05-29 23:50:11.056294', '0', 'g_person', 'email', False, False, False, True, True, False, 'COL_2-1', 'text_input', 'Email', ''), ('f1120b57-c996-4a13-b8e9-ac8aeaa54bbf', '2023-05-29 23:50:11.056294', '0', 'g_person', 'cell_phone', False, False, False, True, True, False, 'COL_2-2', 'text_input', 'Cell', ''), ('39dc03ab-1e95-4e7f-bc87-4b8a470b5d8f', '2023-05-29 23:50:11.056294', '0', 'g_person', 'office_address', False, False, False, True, True, False, 'COL_2-3', 'text_input', '', ''), ('73915fe3-8489-4eb1-8b54-25bda12f4a88', '2023-05-29 23:50:11.056294', '0', 'g_person', 'note', False, False, False, True, True, False, 'COL_2-4', 'text_area', 'Note', ''), ('3019cb46-e2d1-4019-b1e8-15d408ce7441', '2023-05-29 23:50:11.056294', '0', 'g_person', 'person_type', False, False, False, True, True, False, 'COL_3-2', 'selectbox', 'Person Type', ''), ('55ea5912-9b24-4b8d-ae1f-e45b8c16f43b', '2023-05-29 23:50:11.056294', '0', 'g_person', 'award', False, False, Fal ...
# ;

# %%
with DBConn() as _conn:
    _conn.execute(sql_stmt)
    _conn.commit()

# %% [markdown]
# ```
# select  c.table_name, c.column_name, c.data_type, c.*
# from information_schema.columns c
# where 1=1
# and c.table_catalog = 'faculty-Cornell-CS'
# and c.table_schema = 'main'
# and c.table_name in (
# 	--'t_note'
# 	select table_name from information_schema.tables t
# 	where t.table_catalog = 'faculty-Cornell-CS'
# 	and t.table_schema = 'main'
# )
# order by c.table_catalog,c.table_schema,c.table_name, c.ordinal_position
# ```

# %%
def _gen_label(col):
    "Convert table column into form label"
    if col == 'ts_created': return "Created At"
    if "_" not in col:
        if col.upper() in ["URL","ID"]:
            return col.upper()
        elif col.upper() == "TS":
            return "Timestamp"
        return col.capitalize()

    cols = []
    for c in col.split("_"):
        c  = c.strip()
        if not c: continue
        cols.append(c.capitalize())
    return " ".join(cols)

def _prepare_col_props(selected_tbls):
    col_props = {}
    for tbl in selected_tbls:
        cols_def = {}
        for col in TABLE_COLUMNS[tbl]:
            col_def = {}
            for p in PROPS:
                if "is_" in p:
                    col_def.update({p: False})
                elif p == 'form_column':
                    col_def.update({p: "col1-1"})
                elif p == 'widget_type':
                    col_def.update({p: "text_input"})
                else:
                    col_def.update({p: _gen_label(col)})
            cols_def[col] = col_def
        col_props[tbl] = cols_def

    return col_props

def _get_columns(table_name, prop_name="is_visible"):
    cols_bool = []
    cols_text = {}
    for k,v in COLUMN_PROPS[table_name].items():
        if prop_name.startswith("is_") and v.get(prop_name, False):
            cols_bool.append(k)
            
        if not prop_name.startswith("is_"):
            val = v.get(prop_name, "")
            if val:
                cols_text.update({k: val})
    
    return cols_bool or cols_text

def _parse_column_props():
    """parse COLUMN_PROPS map
    """
    col_defs = {}
    for table_name in COLUMN_PROPS.keys():
        defs = {}
        cols_widget_type = {}
        cols_label_text = {}
        for p in PROPS:
            res = _get_columns(table_name, prop_name=p)
            # print(f"{p}: {res}")
            if p == 'widget_type':
                cols_widget_type = res
            elif p == 'label_text':
                cols_label_text = res
            defs[p] = res
            
        # reset label
        for col in cols_widget_type.keys():
            label = cols_label_text.get(col, "")
            if not label:
                label = _gen_label(col)
            cols_label_text.update({col : label})
        # print(cols_label_text)
        defs['label_text'] = cols_label_text
        defs['all_columns'] = list(cols_widget_type.keys())

        # sort form_column alpha-numerically
        # max number of form columns = 3
        # add them
        tmp = {}
        for i in range(1,4):
            m = {k:v for k,v in defs['form_column'].items() if v.startswith(f"col{i}-")}
            tmp[f"col{str(i)}_columns"] = sorted(m, key=m.__getitem__)        
        defs.update(tmp)
        col_defs[table_name] = defs

        
    return col_defs

# %%
sql_stmt = """
select  c.table_name, c.column_name, c.data_type --,  c.*
from information_schema.columns c
where 1=1
--and c.table_catalog like 'faculty-Cornell-CS%'
and c.table_schema = 'main'
and c.table_name in (
	--'t_note'
	select table_name from information_schema.tables t
	where 1=1
	--and t.table_catalog like 'faculty-Cornell-CS%'
	and t.table_schema = 'main'
)
and c.table_name not like 't1_%'
order by c.table_catalog,c.table_schema,c.table_name, c.ordinal_position
;
"""

# %%
with DBConn() as _conn:
    df = pd.read_sql(sql_stmt, _conn)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_9040\496018617.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_stmt, _conn)

# %%
df
# Out:
#          table_name    column_name data_type
# 0    g_column_props     table_name   VARCHAR
# 1    g_column_props       col_name   VARCHAR
# 2    g_column_props  is_system_col   BOOLEAN
# 3    g_column_props    is_user_key   BOOLEAN
# 4    g_column_props    is_required   BOOLEAN
# ..              ...            ...       ...
# 157          t_work           tags   VARCHAR
# 158          t_work           note   VARCHAR
# 159          t_work     ts_created   VARCHAR
# 160          t_work             id   VARCHAR
# 161          t_work             ts   VARCHAR
#
# [162 rows x 3 columns]

# %% [raw]
# df = df[["table_name","column_name"]]

# %%
df.to_records()
# Out:
# rec.array([(  0, 'g_column_props', 'table_name', 'VARCHAR'),
#            (  1, 'g_column_props', 'col_name', 'VARCHAR'),
#            (  2, 'g_column_props', 'is_system_col', 'BOOLEAN'),
#            (  3, 'g_column_props', 'is_user_key', 'BOOLEAN'),
#            (  4, 'g_column_props', 'is_required', 'BOOLEAN'),
#            (  5, 'g_column_props', 'is_visible', 'BOOLEAN'),
#            (  6, 'g_column_props', 'is_editable', 'BOOLEAN'),
#            (  7, 'g_column_props', 'is_clickable', 'BOOLEAN'),
#            (  8, 'g_column_props', 'form_column', 'VARCHAR'),
#            (  9, 'g_column_props', 'widget_type', 'field_ui_type'),
#            ( 10, 'g_column_props', 'label_text', 'VARCHAR'),
#            ( 11, 'g_column_props', 'kwargs', 'VARCHAR'),
#            ( 12, 'g_entity', 'id', 'VARCHAR'),
#            ( 13, 'g_entity', 'uid', 'VARCHAR'),
#            ( 14, 'g_entity', 'ts', 'VARCHAR'),
#            ( 15, 'g_entity', 'entity_type', 'VARCHAR'),
#            ( 16, 'g_entity', 'name', 'VARCHAR'),
#            ( 17, 'g_entity', 'url', 'VARCHAR'),
#            ( 18, 'g_entity', 'note', 'VARCHAR'),
#            ( 19, 'g_note', 'id', 'VARCHAR'),
#            ( 20, 'g_note', 'uid', 'VARCHAR'),
#            ( 21, 'g_note', 'ts', 'VARCHAR'),
#            ( 22, 'g_note', 'name', 'VARCHAR'),
#            ( 23, 'g_note', 'url', 'VARCHAR'),
#            ( 24, 'g_note', 'note', 'VARCHAR'),
#            ( 25, 'g_note', 'tags', 'VARCHAR'),
#            ( 26, 'g_note', 'ref_key', 'VARCHAR'),
#            ( 27, 'g_note', 'ref_val', 'VARCHAR'),
#            ( 28, 'g_person', 'id', 'VARCHAR'),
#            ( 29, 'g_person', 'uid', 'VARCHAR'),
#            ( 30, 'g_person', 'ts', 'VARCHAR'),
#            ( 31, 'g_person', 'person_type', 'VARCHAR'),
#            ( 32, 'g_person', 'name', 'VARCHAR'),
#            ( 33, 'g_person', 'url', 'VARCHAR'),
#            ( 34, 'g_person', 'note', 'VARCHAR'),
#            ( 35, 'g_person', 'email', 'VARCHAR'),
#            ( 36, 'g_person', 'first_name', 'VARCHAR'),
#            ( 37, 'g_person', 'mid_name', 'VARCHAR'),
#            ( 38, 'g_person', 'last_name', 'VARCHAR'),
#            ( 39, 'g_person', 'job_title', 'VARCHAR'),
#            ( 40, 'g_person', 'phd_univ', 'VARCHAR'),
#            ( 41, 'g_person', 'phd_year', 'VARCHAR'),
#            ( 42, 'g_person', 'research_area', 'VARCHAR'),
#            ( 43, 'g_person', 'research_concentration', 'VARCHAR'),
#            ( 44, 'g_person', 'research_focus', 'VARCHAR'),
#            ( 45, 'g_person', 'img_url', 'VARCHAR'),
#            ( 46, 'g_person', 'phone', 'VARCHAR'),
#            ( 47, 'g_person', 'cell_phone', 'VARCHAR'),
#            ( 48, 'g_person', 'office_address', 'VARCHAR'),
#            ( 49, 'g_person', 'department', 'VARCHAR'),
#            ( 50, 'g_person', 'org', 'VARCHAR'),
#            ( 51, 'g_relation', 'id', 'VARCHAR'),
#            ( 52, 'g_relation', 'uid', 'VARCHAR'),
#            ( 53, 'g_relation', 'ts', 'VARCHAR'),
#            ( 54, 'g_relation', 'rel_type', 'VARCHAR'),
#            ( 55, 'g_relation', 'ref_key', 'VARCHAR'),
#            ( 56, 'g_relation', 'ref_val', 'VARCHAR'),
#            ( 57, 'g_relation', 'ref_key_sub', 'VARCHAR'),
#            ( 58, 'g_relation', 'ref_val_sub', 'VARCHAR'),
#            ( 59, 'g_work', 'id', 'VARCHAR'),
#            ( 60, 'g_work', 'uid', 'VARCHAR'),
#            ( 61, 'g_work', 'ts', 'VARCHAR'),
#            ( 62, 'g_work', 'work_type', 'VARCHAR'),
#            ( 63, 'g_work', 'name', 'VARCHAR'),
#            ( 64, 'g_work', 'url', 'VARCHAR'),
#            ( 65, 'g_work', 'note', 'VARCHAR'),
#            ( 66, 'g_work', 'summary', 'VARCHAR'),
#            ( 67, 'g_work', 'authors', 'VARCHAR'),
#            ( 68, 'g_work', 'tags', 'VARCHAR'),
#            ( 69, 't_column_props', 'table_name', 'VARCHAR'),
#            ( 70, 't_column_props', 'col_name', 'VARCHAR'),
#            ( 71, 't_column_props', 'is_system_col', 'BOOLEAN'),
#            ( 72, 't_column_props', 'is_user_key', 'BOOLEAN'),
#            ( 73, 't_column_props', 'is_required', 'BOOLEAN'),
#            ( 74, 't_column_props', 'is_visible', 'BOOLEAN'),
#            ( 75, 't_column_props', 'is_editable', 'BOOLEAN'),
#            ( 76, 't_column_props', 'is_clickable', 'BOOLEAN'),
#            ( 77, 't_column_props', 'form_column', 'VARCHAR'),
#            ( 78, 't_column_props', 'widget_type', 'field_ui_type'),
#            ( 79, 't_column_props', 'label_text', 'VARCHAR'),
#            ( 80, 't_faculty', 'name', 'VARCHAR'),
#            ( 81, 't_faculty', 'job_title', 'VARCHAR'),
#            ( 82, 't_faculty', 'phd_univ', 'VARCHAR'),
#            ( 83, 't_faculty', 'phd_year', 'VARCHAR'),
#            ( 84, 't_faculty', 'research_area', 'VARCHAR'),
#            ( 85, 't_faculty', 'research_concentration', 'VARCHAR'),
#            ( 86, 't_faculty', 'research_focus', 'VARCHAR'),
#            ( 87, 't_faculty', 'url', 'VARCHAR'),
#            ( 88, 't_faculty', 'img_url', 'VARCHAR'),
#            ( 89, 't_faculty', 'phone', 'VARCHAR'),
#            ( 90, 't_faculty', 'email', 'VARCHAR'),
#            ( 91, 't_faculty', 'cell_phone', 'VARCHAR'),
#            ( 92, 't_faculty', 'office_address', 'VARCHAR'),
#            ( 93, 't_faculty', 'department', 'VARCHAR'),
#            ( 94, 't_faculty', 'school', 'VARCHAR'),
#            ( 95, 't_faculty', 'note', 'VARCHAR'),
#            ( 96, 't_note', 'name', 'VARCHAR'),
#            ( 97, 't_note', 'note', 'VARCHAR'),
#            ( 98, 't_note', 'url', 'VARCHAR'),
#            ( 99, 't_note', 'tags', 'VARCHAR'),
#            (100, 't_note', 'ts', 'VARCHAR'),
#            (101, 't_note', 'id', 'VARCHAR'),
#            (102, 't_note', 'ref_type', 'VARCHAR'),
#            (103, 't_note', 'ref_key', 'VARCHAR'),
#            (104, 't_org', 'name', 'VARCHAR'),
#            (105, 't_org', 'url', 'VARCHAR'),
#            (106, 't_org', 'note', 'VARCHAR'),
#            (107, 't_person', 'name', 'VARCHAR'),
#            (108, 't_person', 'url', 'VARCHAR'),
#            (109, 't_person', 'email', 'VARCHAR'),
#            (110, 't_person', 'first_name', 'VARCHAR'),
#            (111, 't_person', 'mid_name', 'VARCHAR'),
#            (112, 't_person', 'last_name', 'VARCHAR'),
#            (113, 't_person', 'note', 'VARCHAR'),
#            (114, 't_person', 'id', 'VARCHAR'),
#            (115, 't_person', 'ts', 'VARCHAR'),
#            (116, 't_person', 'job_title', 'VARCHAR'),
#            (117, 't_person', 'person_type', 'VARCHAR'),
#            (118, 't_person', 'phd_univ', 'VARCHAR'),
#            (119, 't_person', 'phd_year', 'VARCHAR'),
#            (120, 't_person', 'research_area', 'VARCHAR'),
#            (121, 't_person', 'research_concentration', 'VARCHAR'),
#            (122, 't_person', 'research_focus', 'VARCHAR'),
#            (123, 't_person', 'img_url', 'VARCHAR'),
#            (124, 't_person', 'phone', 'VARCHAR'),
#            (125, 't_person', 'cell_phone', 'VARCHAR'),
#            (126, 't_person', 'office_address', 'VARCHAR'),
#            (127, 't_person', 'department', 'VARCHAR'),
#            (128, 't_person', 'school', 'VARCHAR'),
#            (129, 't_person', 'org', 'VARCHAR'),
#            (130, 't_person_team', 'id', 'VARCHAR'),
#            (131, 't_person_team', 'ts', 'VARCHAR'),
#            (132, 't_person_team', 'ref_type', 'VARCHAR'),
#            (133, 't_person_team', 'ref_key', 'VARCHAR'),
#            (134, 't_person_team', 'ref_type_2', 'VARCHAR'),
#            (135, 't_person_team', 'ref_key_2', 'VARCHAR'),
#            (136, 't_person_work', 'id', 'VARCHAR'),
#            (137, 't_person_work', 'ts', 'VARCHAR'),
#            (138, 't_person_work', 'ref_type', 'VARCHAR'),
#            (139, 't_person_work', 'ref_key', 'VARCHAR'),
#            (140, 't_person_work', 'ref_type_2', 'VARCHAR'),
#            (141, 't_person_work', 'ref_key_2', 'VARCHAR'),
#            (142, 't_research_group', 'name', 'VARCHAR'),
#            (143, 't_research_group', 'url', 'VARCHAR'),
#            (144, 't_research_group', 'note', 'VARCHAR'),
#            (145, 't_research_group', 'id', 'VARCHAR'),
#            (146, 't_research_group', 'ts', 'VARCHAR'),
#            (147, 't_team', 'name', 'VARCHAR'),
#            (148, 't_team', 'url', 'VARCHAR'),
#            (149, 't_team', 'note', 'VARCHAR'),
#            (150, 't_team', 'id', 'VARCHAR'),
#            (151, 't_team', 'team_lead', 'VARCHAR'),
#            (152, 't_work', 'type', 'VARCHAR'),
#            (153, 't_work', 'name', 'VARCHAR'),
#            (154, 't_work', 'url', 'VARCHAR'),
#            (155, 't_work', 'summary', 'VARCHAR'),
#            (156, 't_work', 'authors', 'VARCHAR'),
#            (157, 't_work', 'tags', 'VARCHAR'),
#            (158, 't_work', 'note', 'VARCHAR'),
#            (159, 't_work', 'ts_created', 'VARCHAR'),
#            (160, 't_work', 'id', 'VARCHAR'),
#            (161, 't_work', 'ts', 'VARCHAR')],
#           dtype=[('index', '<i8'), ('table_name', 'O'), ('column_name', 'O'), ('data_type', 'O')])

# %%
tbl_map = {}
for idx, tbl, col, typ in df.to_records():
    if tbl not in tbl_map:
        tbl_map[tbl] = [(col,typ)]
    else:
        tmp = tbl_map[tbl]
        tmp.append((col,typ))
        tbl_map[tbl] = tmp
tbl_map
# Out:
# {'g_column_props': [('table_name', 'VARCHAR'),
#   ('col_name', 'VARCHAR'),
#   ('is_system_col', 'BOOLEAN'),
#   ('is_user_key', 'BOOLEAN'),
#   ('is_required', 'BOOLEAN'),
#   ('is_visible', 'BOOLEAN'),
#   ('is_editable', 'BOOLEAN'),
#   ('is_clickable', 'BOOLEAN'),
#   ('form_column', 'VARCHAR'),
#   ('widget_type', 'field_ui_type'),
#   ('label_text', 'VARCHAR'),
#   ('kwargs', 'VARCHAR')],
#  'g_entity': [('id', 'VARCHAR'),
#   ('uid', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('entity_type', 'VARCHAR'),
#   ('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('note', 'VARCHAR')],
#  'g_note': [('id', 'VARCHAR'),
#   ('uid', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('tags', 'VARCHAR'),
#   ('ref_key', 'VARCHAR'),
#   ('ref_val', 'VARCHAR')],
#  'g_person': [('id', 'VARCHAR'),
#   ('uid', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('person_type', 'VARCHAR'),
#   ('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('email', 'VARCHAR'),
#   ('first_name', 'VARCHAR'),
#   ('mid_name', 'VARCHAR'),
#   ('last_name', 'VARCHAR'),
#   ('job_title', 'VARCHAR'),
#   ('phd_univ', 'VARCHAR'),
#   ('phd_year', 'VARCHAR'),
#   ('research_area', 'VARCHAR'),
#   ('research_concentration', 'VARCHAR'),
#   ('research_focus', 'VARCHAR'),
#   ('img_url', 'VARCHAR'),
#   ('phone', 'VARCHAR'),
#   ('cell_phone', 'VARCHAR'),
#   ('office_address', 'VARCHAR'),
#   ('department', 'VARCHAR'),
#   ('org', 'VARCHAR')],
#  'g_relation': [('id', 'VARCHAR'),
#   ('uid', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('rel_type', 'VARCHAR'),
#   ('ref_key', 'VARCHAR'),
#   ('ref_val', 'VARCHAR'),
#   ('ref_key_sub', 'VARCHAR'),
#   ('ref_val_sub', 'VARCHAR')],
#  'g_work': [('id', 'VARCHAR'),
#   ('uid', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('work_type', 'VARCHAR'),
#   ('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('summary', 'VARCHAR'),
#   ('authors', 'VARCHAR'),
#   ('tags', 'VARCHAR')],
#  't_column_props': [('table_name', 'VARCHAR'),
#   ('col_name', 'VARCHAR'),
#   ('is_system_col', 'BOOLEAN'),
#   ('is_user_key', 'BOOLEAN'),
#   ('is_required', 'BOOLEAN'),
#   ('is_visible', 'BOOLEAN'),
#   ('is_editable', 'BOOLEAN'),
#   ('is_clickable', 'BOOLEAN'),
#   ('form_column', 'VARCHAR'),
#   ('widget_type', 'field_ui_type'),
#   ('label_text', 'VARCHAR')],
#  't_faculty': [('name', 'VARCHAR'),
#   ('job_title', 'VARCHAR'),
#   ('phd_univ', 'VARCHAR'),
#   ('phd_year', 'VARCHAR'),
#   ('research_area', 'VARCHAR'),
#   ('research_concentration', 'VARCHAR'),
#   ('research_focus', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('img_url', 'VARCHAR'),
#   ('phone', 'VARCHAR'),
#   ('email', 'VARCHAR'),
#   ('cell_phone', 'VARCHAR'),
#   ('office_address', 'VARCHAR'),
#   ('department', 'VARCHAR'),
#   ('school', 'VARCHAR'),
#   ('note', 'VARCHAR')],
#  't_note': [('name', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('tags', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('id', 'VARCHAR'),
#   ('ref_type', 'VARCHAR'),
#   ('ref_key', 'VARCHAR')],
#  't_org': [('name', 'VARCHAR'), ('url', 'VARCHAR'), ('note', 'VARCHAR')],
#  't_person': [('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('email', 'VARCHAR'),
#   ('first_name', 'VARCHAR'),
#   ('mid_name', 'VARCHAR'),
#   ('last_name', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('id', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('job_title', 'VARCHAR'),
#   ('person_type', 'VARCHAR'),
#   ('phd_univ', 'VARCHAR'),
#   ('phd_year', 'VARCHAR'),
#   ('research_area', 'VARCHAR'),
#   ('research_concentration', 'VARCHAR'),
#   ('research_focus', 'VARCHAR'),
#   ('img_url', 'VARCHAR'),
#   ('phone', 'VARCHAR'),
#   ('cell_phone', 'VARCHAR'),
#   ('office_address', 'VARCHAR'),
#   ('department', 'VARCHAR'),
#   ('school', 'VARCHAR'),
#   ('org', 'VARCHAR')],
#  't_person_team': [('id', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('ref_type', 'VARCHAR'),
#   ('ref_key', 'VARCHAR'),
#   ('ref_type_2', 'VARCHAR'),
#   ('ref_key_2', 'VARCHAR')],
#  't_person_work': [('id', 'VARCHAR'),
#   ('ts', 'VARCHAR'),
#   ('ref_type', 'VARCHAR'),
#   ('ref_key', 'VARCHAR'),
#   ('ref_type_2', 'VARCHAR'),
#   ('ref_key_2', 'VARCHAR')],
#  't_research_group': [('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('id', 'VARCHAR'),
#   ('ts', 'VARCHAR')],
#  't_team': [('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('id', 'VARCHAR'),
#   ('team_lead', 'VARCHAR')],
#  't_work': [('type', 'VARCHAR'),
#   ('name', 'VARCHAR'),
#   ('url', 'VARCHAR'),
#   ('summary', 'VARCHAR'),
#   ('authors', 'VARCHAR'),
#   ('tags', 'VARCHAR'),
#   ('note', 'VARCHAR'),
#   ('ts_created', 'VARCHAR'),
#   ('id', 'VARCHAR'),
#   ('ts', 'VARCHAR')]}

# %%
for tbl in tbl_map.keys():
    cols = tbl_map[tbl] 
    tmp = []
    for col in cols:
        tmp.append(f"{col[0]} {col[1]}")
    col_list = "\n\t    ,".join(tmp)
    print(f"""
        create table {tbl.replace("t_", "g_")} (
            {col_list}
        );\n
    """)
# Out:
#         create table g_column_props (
#             table_name VARCHAR
# 	    ,col_name VARCHAR
# 	    ,is_system_col BOOLEAN
# 	    ,is_user_key BOOLEAN
# 	    ,is_required BOOLEAN
# 	    ,is_visible BOOLEAN
# 	    ,is_editable BOOLEAN
# 	    ,is_clickable BOOLEAN
# 	    ,form_column VARCHAR
# 	    ,widget_type field_ui_type
# 	    ,label_text VARCHAR
# 	    ,kwargs VARCHAR
#         );
#
#
#
#         create table g_entity (
#             id VARCHAR
# 	    ,uid VARCHAR
# 	    ,ts VARCHAR
# 	    ,entity_type VARCHAR
# 	    ,name VARCHAR
# 	    ,url VARCHAR
# 	    ,note VARCHAR
#         );
#
#
#
#         create table g_note (
#             id VARCHAR
# 	    ,uid VARCHAR
# 	    ,ts VARCHAR
# 	    ,name VARCHAR
# 	    ,url VARCHAR
# 	    ,note VARCHAR
# 	    ,tags VARCHAR
# 	    ,ref_key VARCHAR
# 	    ,ref_val VARCHAR
#         );
#
#
#
#         create table g_person (
#             id VARCHAR
# 	    ,uid VARCHAR
# 	    ,ts VARCHAR
# 	    ,person_type VARCHAR
# 	    ,name VARCHAR
# 	    ,url VARCHAR
# 	    ,note VARCHAR
# 	    ,email VARCHAR
# 	    ,first_name VARCHAR
# 	    ,mid_name VARCHAR
# 	    ,last_name VARCHAR
# 	    ,job_title VARCHAR
# 	    ,phd_univ VARCHAR
# 	    ,phd_year VARCHAR
# 	    ,research_area VARCHAR
# 	    ,research_concentration VARCHAR
# 	    ,research_focus VARCHAR
# 	    ,img_url VARCHAR
# 	    ,phone VARCHAR
# 	    ,cell_phone VARCHAR
# 	    ,office_address VARCHAR
# 	    ,department VARCHAR
# 	    ,org VARCHAR
#         );
#
#
#
#         create table g_relation (
#             id VARCHAR
# 	    ,uid VARCHAR
# 	    ,ts VARCHAR
# 	    ,rel_type VARCHAR
# 	    ,ref_key VARCHAR
# 	    ,ref_val VARCHAR
# 	    ,ref_key_sub VARCHAR
# 	    ,ref_val_sub VARCHAR
#         );
#
#
#
#         create table g_work (
#             id VARCHAR
# 	    ,uid VARCHAR
# 	    ,ts VARCHAR
# 	    ,work_type VARCHAR
# 	    ,name VARCHAR
# 	    ,url VARCHAR
# 	    ,note VARCHAR
# 	    ,summary VARCHAR
# 	    ,authors VARCHAR
# 	    ,tags VARCHAR
#         );
#
#
#
#         create table g_column_props (
#             table_name VARCHAR
# 	    ,col_name VARCHAR
# 	    ,is_system_col BOOLEAN
# 	    ,is_user_key BOOLEAN
# 	    ,is_required BOOLEAN
# 	    ,is_visible BOOLEAN
# 	    ,is_editable BOOLEAN
# 	    ,is_clickable BOOLEAN
# 	    ,form_column VARCHAR
# 	    ,widget_type field_ui_type
# 	    ,label_text VARCHAR
#         );
#
#
#
#         create table g_faculty (
#             name VARCHAR
# 	    ,job_title VARCHAR
# 	    ,phd_univ VARCHAR
# 	    ,phd_year VARCHAR
# 	    ,research_area VARCHAR
# 	    ,research_concentration VARCHAR
# 	    ,research_focus VARCHAR
# 	    ,url VARCHAR
# 	    ,img_url VARCHAR
# 	    ,phone VARCHAR
# 	    ,email VARCHAR
# 	    ,cell_phone VARCHAR
# 	    ,office_address VARCHAR
# 	    ,department VARCHAR
# 	    ,school VARCHAR
# 	    ,note VARCHAR
#         );
#
#
#
#         create table g_note (
#             name VARCHAR
# 	    ,note VARCHAR
# 	    ,url VARCHAR
# 	    ,tags VARCHAR
# 	    ,ts VARCHAR
# 	    ,id VARCHAR
# 	    ,ref_type VARCHAR
# 	    ,ref_key VARCHAR
#         );
#
#
#
#         create table g_org (
#             name VARCHAR
# 	    ,url VARCHAR
# 	    ,note VARCHAR
#         );
#
#
#
#         create table g_person (
#             name VARCHAR
# 	    ,url VARCHAR
# 	    ,email VARCHAR
# 	    ,first_name VARCHAR
# 	    ,mid_name VARCHAR
# 	    ,last_name VARCHAR
# 	    ,note VARCHAR
# 	    ,id VARCHAR
# 	    ,ts VARCHAR
# 	    ,job_title VARCHAR
# 	    ,person_type VARCHAR
# 	    ,phd_univ VARCHAR
# 	    ,phd_year VARCHAR
# 	    ,research_area VARCHAR
# 	    ,research_concentration VARCHAR
# 	    ,research_focus VARCHAR
# 	    ,img_url VARCHAR
# 	    ,phone VARCHAR
# 	    ,cell_phone VARCHAR
# 	    ,office_address VARCHAR
# 	    ,department VARCHAR
# 	    ,school VARCHAR
# 	    ,org VARCHAR
#         );
#
#
#
#         create table g_person_team (
#             id VARCHAR
# 	    ,ts VARCHAR
# 	    ,ref_type VARCHAR
# 	    ,ref_key VARCHAR
# 	    ,ref_type_2 VARCHAR
# 	    ,ref_key_2 VARCHAR
#         );
#
#
#
#         create table g_person_work (
#             id VARCHAR
# 	    ,ts VARCHAR
# 	    ,ref_type VARCHAR
# 	    ,ref_key VARCHAR
# 	    ,ref_type_2 VARCHAR
# 	    ,ref_key_2 VARCHAR
#         );
#
#
#
#         create table g_research_group (
#             name VARCHAR
# 	    ,url VARCHAR
# 	    ,note VARCHAR
# 	    ,id VARCHAR
# 	    ,ts VARCHAR
#         );
#
#
#
#         create table g_team (
#             name VARCHAR
# 	    ,url VARCHAR
# 	    ,note VARCHAR
# 	    ,id VARCHAR
# 	    ,team_lead VARCHAR
#         );
#
#
#
#         create table g_work (
#             type VARCHAR
# 	    ,name VARCHAR
# 	    ,url VARCHAR
# 	    ,summary VARCHAR
# 	    ,authors VARCHAR
# 	    ,tags VARCHAR
# 	    ,note VARCHAR
# 	    ,ts_created VARCHAR
# 	    ,id VARCHAR
# 	    ,ts VARCHAR
#         );

# %%
df.to_csv("tab_cols-2023-04-28.csv", index=False)

# %%
df_list= df.groupby('table_name')['column_name', 'data_type'].apply(list)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_9040\1589112563.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_list= df.groupby('table_name')['column_name', 'data_type'].apply(list)

# %%
TABLE_COLUMNS = df_list.to_dict()

# %%
TABLE_COLUMNS
# Out:
# {'g_column_props': ['column_name', 'data_type'],
#  'g_entity': ['column_name', 'data_type'],
#  'g_note': ['column_name', 'data_type'],
#  'g_person': ['column_name', 'data_type'],
#  'g_relation': ['column_name', 'data_type'],
#  'g_work': ['column_name', 'data_type'],
#  't_column_props': ['column_name', 'data_type'],
#  't_faculty': ['column_name', 'data_type'],
#  't_note': ['column_name', 'data_type'],
#  't_org': ['column_name', 'data_type'],
#  't_person': ['column_name', 'data_type'],
#  't_person_team': ['column_name', 'data_type'],
#  't_person_work': ['column_name', 'data_type'],
#  't_research_group': ['column_name', 'data_type'],
#  't_team': ['column_name', 'data_type'],
#  't_work': ['column_name', 'data_type']}

# %%
PROPS = [c for c in TABLE_COLUMNS['t_column_props'] if c not in ['table_name','col_name']]

# %%
PROPS
# Out:
# ['column_name', 'data_type']

# %%
TABLE_COLUMNS.keys()
# Out:
# dict_keys(['g_column_props', 'g_entity', 'g_note', 'g_person', 'g_relation', 'g_work', 't_column_props', 't_faculty', 't_note', 't_org', 't_person', 't_person_team', 't_person_work', 't_research_group', 't_team', 't_work'])

# %%
COLUMN_PROPS.keys()
# Out:
# dict_keys(['t_note', 't_team', 't_work', 't_person_team', 't_person_work', 't_research_group', 't_person'])

# %%
selected_tbls = [t for t in TABLE_COLUMNS.keys() if t not in [
            "t_person_team", "t_person_work", "t_team", "t_work", 't_note', 't_column_props']]

# %%
selected_tbls = ['t_person', 't_research_group']

# %%
col_props = _prepare_col_props(selected_tbls)

# %%
with open("col_props-1.json", "w") as f:
    f.write(json.dumps(col_props))

# %%
from config_g import *

# %%
COLUMN_DEFS = _parse_column_props()

# %%
COLUMN_DEFS
# Out:
# {'g_entity': {'is_system_col': ['id'],
#   'is_user_key': ['name'],
#   'is_required': ['name', 'id'],
#   'is_visible': ['name', 'url', 'entity_type', 'id', 'note'],
#   'is_editable': ['name', 'url', 'entity_type', 'note'],
#   'is_clickable': ['url'],
#   'form_column': {'name': 'col1-1',
#    'url': 'col1-2',
#    'entity_type': 'col1-3',
#    'id': 'col2-1',
#    'note': 'col2-2'},
#   'widget_type': {'name': 'text_input',
#    'url': 'text_input',
#    'entity_type': 'selectbox',
#    'id': 'text_input',
#    'note': 'text_area'},
#   'label_text': {'name': 'Name',
#    'url': 'URL',
#    'id': 'ID',
#    'note': 'Note',
#    'entity_type': 'Entity Type'},
#   'kwargs': {},
#   'all_columns': ['name', 'url', 'entity_type', 'id', 'note'],
#   'col1_columns': ['name', 'url', 'entity_type'],
#   'col2_columns': ['id', 'note'],
#   'col3_columns': []},
#  'g_person': {'is_system_col': ['id'],
#   'is_user_key': ['name'],
#   'is_required': ['name', 'id'],
#   'is_visible': ['name',
#    'url',
#    'email',
#    'job_title',
#    'research_area',
#    'id',
#    'person_type',
#    'cell_phone',
#    'note'],
#   'is_editable': ['name',
#    'url',
#    'email',
#    'job_title',
#    'research_area',
#    'person_type',
#    'cell_phone',
#    'note'],
#   'is_clickable': ['url'],
#   'form_column': {'name': 'col1-1',
#    'url': 'col1-2',
#    'email': 'col1-3',
#    'job_title': 'col1-4',
#    'research_area': 'col1-5',
#    'id': 'col2-1',
#    'person_type': 'col2-2',
#    'cell_phone': 'col2-3',
#    'note': 'col2-4'},
#   'widget_type': {'name': 'text_input',
#    'url': 'text_input',
#    'email': 'text_input',
#    'job_title': 'text_input',
#    'research_area': 'text_input',
#    'id': 'text_input',
#    'person_type': 'selectbox',
#    'cell_phone': 'text_input',
#    'note': 'text_area'},
#   'label_text': {'name': 'Name',
#    'url': 'URL',
#    'email': 'Email',
#    'job_title': 'Job Title',
#    'research_area': 'Research Area',
#    'id': 'ID',
#    'person_type': 'Person Type',
#    'cell_phone': 'Cell Phone',
#    'note': 'Note'},
#   'kwargs': {},
#   'all_columns': ['name',
#    'url',
#    'email',
#    'job_title',
#    'research_area',
#    'id',
#    'person_type',
#    'cell_phone',
#    'note'],
#   'col1_columns': ['name', 'url', 'email', 'job_title', 'research_area'],
#   'col2_columns': ['id', 'person_type', 'cell_phone', 'note'],
#   'col3_columns': []},
#  'g_note': {'is_system_col': ['id', 'ts'],
#   'is_user_key': ['name'],
#   'is_required': ['name', 'id'],
#   'is_visible': ['name', 'url', 'tags', 'ref_key', 'id', 'note', 'ref_val'],
#   'is_editable': ['name', 'url', 'tags', 'ref_key', 'note', 'ref_val'],
#   'is_clickable': ['url'],
#   'form_column': {'name': 'col1-1',
#    'url': 'col1-2',
#    'tags': 'col1-3',
#    'ref_key': 'col1-4',
#    'id': 'col2-1',
#    'note': 'col2-2',
#    'ref_val': 'col2-3'},
#   'widget_type': {'name': 'text_input',
#    'url': 'text_input',
#    'tags': 'text_input',
#    'ref_key': 'text_input',
#    'id': 'text_input',
#    'note': 'text_area',
#    'ref_val': 'text_input'},
#   'label_text': {'url': 'URL',
#    'id': 'ID',
#    'name': 'Name',
#    'tags': 'Tags',
#    'ref_key': 'Ref Key',
#    'note': 'Note',
#    'ref_val': 'Ref Val'},
#   'kwargs': {},
#   'all_columns': ['name', 'url', 'tags', 'ref_key', 'id', 'note', 'ref_val'],
#   'col1_columns': ['name', 'url', 'tags', 'ref_key'],
#   'col2_columns': ['id', 'note', 'ref_val'],
#   'col3_columns': []},
#  'g_work': {'is_system_col': ['id', 'ts'],
#   'is_user_key': ['name'],
#   'is_required': ['name', 'id'],
#   'is_visible': ['name',
#    'url',
#    'authors',
#    'summary',
#    'id',
#    'work_type',
#    'tags',
#    'note'],
#   'is_editable': ['name',
#    'url',
#    'authors',
#    'summary',
#    'work_type',
#    'tags',
#    'note'],
#   'is_clickable': ['url'],
#   'form_column': {'name': 'col1-1',
#    'url': 'col1-2',
#    'authors': 'col1-3',
#    'summary': 'col1-4',
#    'id': 'col2-1',
#    'work_type': 'col2-2',
#    'tags': 'col2-3',
#    'note': 'col2-4',
#    'ts': 'col3-2'},
#   'widget_type': {'name': 'text_input',
#    'url': 'text_input',
#    'authors': 'text_input',
#    'summary': 'text_area',
#    'id': 'text_input',
#    'work_type': 'selectbox',
#    'tags': 'text_input',
#    'note': 'text_area',
#    'ts': 'text_input'},
#   'label_text': {'name': 'Name',
#    'url': 'URL',
#    'authors': 'Authors',
#    'summary': 'Summary',
#    'id': 'ID',
#    'work_type': 'Work Type',
#    'tags': 'Tags',
#    'note': 'Note',
#    'ts': 'Timestamp'},
#   'kwargs': {},
#   'all_columns': ['name',
#    'url',
#    'authors',
#    'summary',
#    'id',
#    'work_type',
#    'tags',
#    'note',
#    'ts'],
#   'col1_columns': ['name', 'url', 'authors', 'summary'],
#   'col2_columns': ['id', 'work_type', 'tags', 'note'],
#   'col3_columns': ['ts']},
#  'g_relation': {'is_system_col': ['id'],
#   'is_user_key': {},
#   'is_required': ['id'],
#   'is_visible': ['rel_type'],
#   'is_editable': ['rel_type'],
#   'is_clickable': {},
#   'form_column': {'rel_type': 'col1-1',
#    'ref_key': 'col1-2',
#    'ref_val': 'col1-3',
#    'id': 'col2-1',
#    'ref_key_sub': 'col2-2',
#    'ref_val_sub': 'col2-3'},
#   'widget_type': {'rel_type': 'text_input',
#    'ref_key': 'text_input',
#    'ref_val': 'text_input',
#    'id': 'text_input',
#    'ref_key_sub': 'text_input',
#    'ref_val_sub': 'text_input'},
#   'label_text': {'rel_type': 'Rel Type',
#    'ref_key': 'Ref Key',
#    'ref_val': 'Ref Val',
#    'id': 'ID',
#    'ref_key_sub': 'Ref Key Sub',
#    'ref_val_sub': 'Ref Val Sub'},
#   'kwargs': {},
#   'all_columns': ['rel_type',
#    'ref_key',
#    'ref_val',
#    'id',
#    'ref_key_sub',
#    'ref_val_sub'],
#   'col1_columns': ['rel_type', 'ref_key', 'ref_val'],
#   'col2_columns': ['id', 'ref_key_sub', 'ref_val_sub'],
#   'col3_columns': []}}

# %%
table_name = "g_person"
COL_DEFS = COLUMN_DEFS[table_name]
visible_columns = COL_DEFS["is_visible"]
system_columns = COL_DEFS["is_system_col"]
form_columns = COL_DEFS["form_column"]
col_labels = COL_DEFS["label_text"]
widget_types = COL_DEFS["widget_type"]

# %%
key_columns = COL_DEFS["is_user_key"]
key_columns
# Out:
# ['name']

# %%
s = "publication, preprint, talk, poster, project, startup, company"
WORK_TYPES = [c.strip() for c in s.split(",") if c.strip()]
WORK_TYPES
# Out:
# ['publication', 'preprint', 'talk', 'poster', 'project', 'startup', 'company']

# %%
form_cols = {
    "note": "col2-2",
    "url": "col1-2",
    "name": "col1-1",
    "id": "col2-1",
}

res = {}
for i in range(1,4):
    m = {k:v for k,v in form_cols.items() if v.startswith(f"col{i}-")}
    res[f"col{str(i)}_columns"] = sorted(m, key=m.__getitem__)

# %%
res
# Out:
# {'col1_columns': ['name', 'url'],
#  'col2_columns': ['id', 'note'],
#  'col3_columns': []}

# %%
res2 = {}

# %%
res2.update(res)

# %%
res2
# Out:
# {'col1_columns': ['name', 'url'],
#  'col2_columns': ['id', 'note'],
#  'col3_columns': []}

# %%
c = [1,2]
c2 = c.copy()
c2
# Out:
# [1, 2]

# %%
def _move_sys_col_end(cols, sys_cols=["id"]):
    """move id, ts sys column to last position
    """
    new_sys_cols = []
    new_cols = []
    for c in cols:
        if c in sys_cols:
            new_sys_cols.append(c)
        else:
            new_cols.append(c)
    if sys_cols:
        if len(new_cols) == len(cols):
            return new_cols
        else:
            return new_cols + new_sys_cols
    else:
        return cols

# %%
cols = ["name", "id", "url", "ts", "note"]
_move_sys_col_end(cols, sys_cols=["ts","id", "ts2"])
# Out:
# ['name', 'url', 'note', 'id', 'ts']

# %%
inter_col_str = """
id, ts, rel_type, 
            ref_tab, ref_key, ref_val, 
            ref_tab_sub, ref_key_sub, ref_val_sub
"""
inter_cols = [c.strip() for c in inter_col_str.split(",") if c.strip()]

# %%
print(inter_cols)
# Out:
# ['id', 'ts', 'rel_type', 'ref_tab', 'ref_key', 'ref_val', 'ref_tab_sub', 'ref_key_sub', 'ref_val_sub']

# %%
x = "['id', 'ts', 'rel_type', 'ref_tab', 'ref_key', 'ref_val', 'ref_tab_sub', 'ref_key_sub', 'ref_val_sub']".replace("'","")

# %%
x
# Out:
# '[id, ts, rel_type, ref_tab, ref_key, ref_val, ref_tab_sub, ref_key_sub, ref_val_sub]'
