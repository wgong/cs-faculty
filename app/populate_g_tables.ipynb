# %% [markdown]
# This notebook migrates test data from t_* tables to g_* tables,
#
# then port  `app_poc.py` to `app_g.py`

# %%
import pandas as pd 
from db import *
from config_poc import *

pd.set_option('display.max_columns', None)

# %%
sql_stmt = """
select  c.table_name, c.column_name --, c.data_type,  c.*
from information_schema.columns c
where 1=1
--and c.table_catalog like 'faculty-Cornell-CS%'
and c.table_schema = 'main'
and c.table_name like 'g_%'
order by c.table_catalog,c.table_schema,c.table_name, c.ordinal_position
;
"""

# %%
with DBConn() as _conn:
    df = pd.read_sql(sql_stmt, _conn)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\496018617.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(sql_stmt, _conn)

# %%
df
# Out:
#         table_name    column_name
# 0   g_column_props     table_name
# 1   g_column_props       col_name
# 2   g_column_props  is_system_col
# 3   g_column_props    is_user_key
# 4   g_column_props    is_required
# ..             ...            ...
# 64          g_work            url
# 65          g_work           note
# 66          g_work        summary
# 67          g_work        authors
# 68          g_work           tags
#
# [69 rows x 2 columns]

# %%
df.to_csv("g_table_columns.csv", index=False)

# %%
uid = '0'

# %% [markdown]
# ## g_note

# %%
table_name = "g_note"
src_table_name = table_name.replace("g_", "t_")

# %%
with DBConn() as _conn:
    df = pd.read_sql(f"""
        select * from {src_table_name};
    """, _conn)
df
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\108093257.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(f"""
#                                                 name  \
# 0                            Campbell Research Group
# 1                                   Cornell AI Group
# 2                               Kevin Tang Home page
# 3                             AI is eating the world
# 4  Building Human Intelligence at Scale, to Save ...
#
#                                                 note  \
# 0  Our group works on algorithms and experimental...
# 1                   this group has over 50 faculties
# 2  I teach in the School of ECE (Electrical and C...
# 3                                               None
# 4  Po-Shen Loh is a math professor, researcher, a...
#
#                                                  url               tags  \
# 0                  https://campbell.mae.cornell.edu/  robotics autonomy
# 1             https://www.cs.cornell.edu/research/ai                 AI
# 2               http://people.ece.cornell.edu/atang/        Network, AI
# 3  https://www.forbes.com/sites/cognitiveworld/20...                 AI
# 4        https://www.youtube.com/watch?v=oO-akX66i24      AI, education
#
#                            ts  \
# 0  2023-04-08 22:02:22.899622
# 1  2023-04-08 18:41:24.944832
# 2  2023-04-20 22:27:15.156655
# 3  2023-04-20 22:29:07.651777
# 4                        None
#
#                                                  id  ref_type  \
# 0              c1b08a22-80bf-4869-99d5-cc4656dde20d      None
# 1              531160e6-bdf1-40e3-ab11-8307d4b2f95b      None
# 2  t_faculty # http://people.ece.cornell.edu/atang/  t_person
# 3              d3bf60a0-4445-4662-927a-c965de9227be      None
# 4              9b72a022-bea2-4658-9be2-491565a6bb1b      None
#
#                                 ref_key
# 0                                  None
# 1                                  None
# 2  http://people.ece.cornell.edu/atang/
# 3                                  None
# 4                                  None

# %%
cols_str = """
id
uid
ts
name
url
note
tags
ref_key
ref_val
"""
cols = [c.strip() for c in cols_str.split("\n") if c.strip()]
cols
# Out:
# ['id', 'uid', 'ts', 'name', 'url', 'note', 'tags', 'ref_key', 'ref_val']

# %%
print("\n, ".join(cols))
# Out:
# id
# , uid
# , ts
# , name
# , url
# , note
# , tags
# , ref_key
# , ref_val

# %%
col_lst = "\n, ".join(cols)

# %%
insert_sql = f"""
insert into {table_name} ({col_lst})
select uuid()
    , '{uid}'
    , now()
    , name
    , url
    , note
    , tags
    , case 
        when ref_type is NULL then NULL
        else 'g_person#url'
      end
    , ref_key
from {src_table_name}
;
"""

# %%
print(insert_sql)
# Out:
# insert into g_note (id
# , uid
# , ts
# , name
# , url
# , note
# , tags
# , ref_key
# , ref_val)
# select uuid()
#     , '0'
#     , now()
#     , name
#     , url
#     , note
#     , tags
#     , case
#         when ref_type is NULL then NULL
#         else 'g_person#url'
#       end
#     , ref_key
# from t_note
# ;

# %%
with DBConn() as _conn:
    df_test = pd.read_sql(f"""
select uuid()
    , '0'
    , now()
    , name
    , url
    , note
    , tags
    , case 
        when ref_type is NULL then NULL
        else 'g_person#url'
      end
    , ref_key
from t_note
    """, _conn)
df_test
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\3845250933.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test = pd.read_sql(f"""
#                                  uuid() '0'                   now()  \
# 0  54aa40bf-e646-4a2d-ab03-c0d2e6462dd4   0 2023-04-26 02:22:03.839
# 1  dd4096ab-bb15-4a73-a43d-689337aec274   0 2023-04-26 02:22:03.839
# 2  a1cbe99c-d788-4d2c-9fba-240e3aff09f1   0 2023-04-26 02:22:03.839
# 3  60f47627-d7c8-4771-b70a-a38a9d676966   0 2023-04-26 02:22:03.839
# 4  54e437cd-d377-4ebb-9876-65957d23c798   0 2023-04-26 02:22:03.839
#
#                                                 name  \
# 0                            Campbell Research Group
# 1                                   Cornell AI Group
# 2                               Kevin Tang Home page
# 3                             AI is eating the world
# 4  Building Human Intelligence at Scale, to Save ...
#
#                                                  url  \
# 0                  https://campbell.mae.cornell.edu/
# 1             https://www.cs.cornell.edu/research/ai
# 2               http://people.ece.cornell.edu/atang/
# 3  https://www.forbes.com/sites/cognitiveworld/20...
# 4        https://www.youtube.com/watch?v=oO-akX66i24
#
#                                                 note               tags  \
# 0  Our group works on algorithms and experimental...  robotics autonomy
# 1                   this group has over 50 faculties                 AI
# 2  I teach in the School of ECE (Electrical and C...        Network, AI
# 3                                               None                 AI
# 4  Po-Shen Loh is a math professor, researcher, a...      AI, education
#
#   CASE  WHEN ((ref_type IS NULL)) THEN (NULL) ELSE 'g_person#url' END  \
# 0                                               None
# 1                                               None
# 2                                       g_person#url
# 3                                               None
# 4                                               None
#
#                                 ref_key
# 0                                  None
# 1                                  None
# 2  http://people.ece.cornell.edu/atang/
# 3                                  None
# 4                                  None

# %% [markdown]
# Looks good

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test = pd.read_sql(f"select * from {table_name};", _conn)
df_test
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\1064854284.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test = pd.read_sql(f"select * from {table_name};", _conn)
#                                      id uid                          ts  \
# 0  d4f3a966-4d8b-4b8c-81b5-42dae8d459da   0  2023-04-25 22:23:47.173-04
# 1  cd7ba169-075b-4611-96da-8330beed0ddd   0  2023-04-25 22:23:47.173-04
# 2  066179d7-712b-4def-bdbe-053ad509b368   0  2023-04-25 22:23:47.173-04
# 3  b030a4f5-8124-4360-842a-8a99366acb8c   0  2023-04-25 22:23:47.173-04
# 4  391c7462-eeee-43a3-8518-f09df1aab21c   0  2023-04-25 22:23:47.173-04
#
#                                                 name  \
# 0                            Campbell Research Group
# 1                                   Cornell AI Group
# 2                               Kevin Tang Home page
# 3                             AI is eating the world
# 4  Building Human Intelligence at Scale, to Save ...
#
#                                                  url  \
# 0                  https://campbell.mae.cornell.edu/
# 1             https://www.cs.cornell.edu/research/ai
# 2               http://people.ece.cornell.edu/atang/
# 3  https://www.forbes.com/sites/cognitiveworld/20...
# 4        https://www.youtube.com/watch?v=oO-akX66i24
#
#                                                 note               tags  \
# 0  Our group works on algorithms and experimental...  robotics autonomy
# 1                   this group has over 50 faculties                 AI
# 2  I teach in the School of ECE (Electrical and C...        Network, AI
# 3                                               None                 AI
# 4  Po-Shen Loh is a math professor, researcher, a...      AI, education
#
#         ref_key                               ref_val
# 0          None                                  None
# 1          None                                  None
# 2  g_person#url  http://people.ece.cornell.edu/atang/
# 3          None                                  None
# 4          None                                  None

# %% [markdown]
# ## g_work

# %%
table_name = "g_work"
src_table_name = table_name.replace("g_", "t_")

# %%
with DBConn() as _conn:
    df_test = pd.read_sql(f"""
        select * from {src_table_name};
    """, _conn)
df_test
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\2841525488.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test = pd.read_sql(f"""
#           type                                               name  \
# 0  publication  Task-aware Privacy Preservation for Multi-dime...
# 1  publication  Data Sharing and Compression for Cooperative N...
# 2  publication  On upper bounding Shannon capacity of graph th...
# 3  publication  Routing Stability in Hybrid Software-Defined N...
#
#                                                  url  \
# 0  http://people.ece.cornell.edu/atang/pub/22/ICM...
# 1  http://people.ece.cornell.edu/atang/pub/21/Neu...
# 2  http://people.ece.cornell.edu/atang/pub/19/opt...
# 3  http://people.ece.cornell.edu/atang/pub/19/ToN...
#
#                                              summary  \
# 0  Extensive experiments demonstrate that our tas...
# 1  we present theoretical compression results for...
# 2   In this paper, we consider the\npossibility o...
# 3   The design is implemented and extensively tes...
#
#                                              authors  tags  note ts_created  \
# 0                 J. Cheng, A. Tang and S. Chinchali  None  None       None
# 1  J. Cheng, M. Pavone, S. Katti, S. Chinchali, a...  None  None       None
# 2                                Yingjie Bi,  Ao Tan  None  None       None
# 3         S. Tseng, A. Tang, G. Choudhury and S. Tse  None  test       None
#
#                                      id    ts
# 0             atang/pub/22/ICML2022.pdf  None
# 1         atang/pub/21/NeurIPS-2021.pdf  None
# 2  b62cf974-c5e4-494a-a29c-e34576bb1ec2  None
# 3  6456ab1c-84e3-4207-b39c-f24937654d82  None

# %%
cols_str = """
id
uid
ts
work_type
name
url
note
summary
authors
tags

"""
cols = [c.strip() for c in cols_str.split("\n") if c.strip()]
cols
# Out:
# ['id',
#  'uid',
#  'ts',
#  'work_type',
#  'name',
#  'url',
#  'note',
#  'summary',
#  'authors',
#  'tags']

# %%
col_lst = "\n, ".join(cols)
print(col_lst)
# Out:
# id
# , uid
# , ts
# , work_type
# , name
# , url
# , note
# , summary
# , authors
# , tags

# %%
df_test.columns
# Out:
# Index(['type', 'name', 'url', 'summary', 'authors', 'tags', 'note',
#        'ts_created', 'id', 'ts'],
#       dtype='object')

# %%
insert_sql = f"""
insert into {table_name} ({col_lst})
select id
    , '{uid}'
    , now()
    , type
    , name
    , url
    , note
    , summary
    , authors
    , tags
from {src_table_name}
;
"""

# %%
print(insert_sql)
# Out:
# insert into g_work (id
# , uid
# , ts
# , work_type
# , name
# , url
# , note
# , summary
# , authors
# , tags)
# select id
#     , '0'
#     , now()
#     , type
#     , name
#     , url
#     , note
#     , summary
#     , authors
#     , tags
# from t_work
# ;

# %%
with DBConn() as _conn:
    df_test2 = pd.read_sql(f"""
select id
    , '0'
    , now()
    , type
    , name
    , url
    , note
    , summary
    , authors
    , tags
from t_work
    """, _conn)
df_test2
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\2607157703.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test2 = pd.read_sql(f"""
#                                      id '0'                   now()  \
# 0             atang/pub/22/ICML2022.pdf   0 2023-04-26 02:38:25.947
# 1         atang/pub/21/NeurIPS-2021.pdf   0 2023-04-26 02:38:25.947
# 2  b62cf974-c5e4-494a-a29c-e34576bb1ec2   0 2023-04-26 02:38:25.947
# 3  6456ab1c-84e3-4207-b39c-f24937654d82   0 2023-04-26 02:38:25.947
#
#           type                                               name  \
# 0  publication  Task-aware Privacy Preservation for Multi-dime...
# 1  publication  Data Sharing and Compression for Cooperative N...
# 2  publication  On upper bounding Shannon capacity of graph th...
# 3  publication  Routing Stability in Hybrid Software-Defined N...
#
#                                                  url  note  \
# 0  http://people.ece.cornell.edu/atang/pub/22/ICM...  None
# 1  http://people.ece.cornell.edu/atang/pub/21/Neu...  None
# 2  http://people.ece.cornell.edu/atang/pub/19/opt...  None
# 3  http://people.ece.cornell.edu/atang/pub/19/ToN...  test
#
#                                              summary  \
# 0  Extensive experiments demonstrate that our tas...
# 1  we present theoretical compression results for...
# 2   In this paper, we consider the\npossibility o...
# 3   The design is implemented and extensively tes...
#
#                                              authors  tags
# 0                 J. Cheng, A. Tang and S. Chinchali  None
# 1  J. Cheng, M. Pavone, S. Katti, S. Chinchali, a...  None
# 2                                Yingjie Bi,  Ao Tan  None
# 3         S. Tseng, A. Tang, G. Choudhury and S. Tse  None

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"select * from {table_name};", _conn)
df_test3
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\1942543153.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"select * from {table_name};", _conn)
#                                      id uid                          ts  \
# 0             atang/pub/22/ICML2022.pdf   0  2023-04-25 22:39:21.303-04
# 1         atang/pub/21/NeurIPS-2021.pdf   0  2023-04-25 22:39:21.303-04
# 2  b62cf974-c5e4-494a-a29c-e34576bb1ec2   0  2023-04-25 22:39:21.303-04
# 3  6456ab1c-84e3-4207-b39c-f24937654d82   0  2023-04-25 22:39:21.303-04
#
#      work_type                                               name  \
# 0  publication  Task-aware Privacy Preservation for Multi-dime...
# 1  publication  Data Sharing and Compression for Cooperative N...
# 2  publication  On upper bounding Shannon capacity of graph th...
# 3  publication  Routing Stability in Hybrid Software-Defined N...
#
#                                                  url  note  \
# 0  http://people.ece.cornell.edu/atang/pub/22/ICM...  None
# 1  http://people.ece.cornell.edu/atang/pub/21/Neu...  None
# 2  http://people.ece.cornell.edu/atang/pub/19/opt...  None
# 3  http://people.ece.cornell.edu/atang/pub/19/ToN...  test
#
#                                              summary  \
# 0  Extensive experiments demonstrate that our tas...
# 1  we present theoretical compression results for...
# 2   In this paper, we consider the\npossibility o...
# 3   The design is implemented and extensively tes...
#
#                                              authors  tags
# 0                 J. Cheng, A. Tang and S. Chinchali  None
# 1  J. Cheng, M. Pavone, S. Katti, S. Chinchali, a...  None
# 2                                Yingjie Bi,  Ao Tan  None
# 3         S. Tseng, A. Tang, G. Choudhury and S. Tse  None

# %% [markdown]
# ## g_person

# %%
table_name = "g_person"
src_table_name = table_name.replace("g_", "t_")

# %%
with DBConn() as _conn:
    df_src = pd.read_sql(f"""
        select * from {src_table_name};
    """, _conn)

# %%
df_src.head(3)
# Out:
#                   name                                    url  \
# 0         Yuchong Geng        https://yuchong-geng.github.io/
# 1      Faraz Farahvash  http://networks.ece.cornell.edu/faraz
# 2  Mohamed Abdelfattah               https://www.mohsaied.com
#
#                email first_name mid_name  last_name  note  \
# 0  yg534@cornell.edu    Yuchong     None       Geng  None
# 1  ff227@cornell.edu      Faraz     None  Farahvash  None
# 2                          None     None       None  None
#
#                                      id                          ts  \
# 0                     yg534@cornell.edu                        None
# 1                     ff227@cornell.edu                        None
# 2  409a467e-159e-411e-aedf-206e0ce0d71e  2023-04-23 14:48:37.555-04
#
#              job_title person_type      phd_univ phd_year  \
# 0                 None     student          None     None
# 1                 None     student          None     None
# 2  Assistant Professor     faculty  Univ Toronto     2016
#
#                                research_area   research_concentration  \
# 0                          AI Network System                     None
# 1                                       None                     None
# 2  Artificial Intelligence, Machine Learning  Artificial Intelligence
#
#   research_focus                                            img_url phone  \
# 0           None                                               None  None
# 1           None                                               None  None
# 2                 https://www.cs.cornell.edu/sites/default/files...
#
#   cell_phone office_address  \
# 0       None           None
# 1       None           None
# 2
#
#                                           department school   org
# 0                                               None   None  None
# 1                                               None   None  None
# 2  Electrical and Computer Engineering, Cornell T...         None

# %%
cols_str = """
id
uid
ts
person_type
name
url
note
email
first_name
mid_name
last_name
job_title
phd_univ
phd_year
research_area
research_concentration
research_focus
img_url
phone
cell_phone
office_address
department
org

"""
cols = [c.strip() for c in cols_str.split("\n") if c.strip()]
cols
# Out:
# ['id',
#  'uid',
#  'ts',
#  'person_type',
#  'name',
#  'url',
#  'note',
#  'email',
#  'first_name',
#  'mid_name',
#  'last_name',
#  'job_title',
#  'phd_univ',
#  'phd_year',
#  'research_area',
#  'research_concentration',
#  'research_focus',
#  'img_url',
#  'phone',
#  'cell_phone',
#  'office_address',
#  'department',
#  'org']

# %%
col_lst = "\n, ".join(cols)
print(col_lst)
# Out:
# id
# , uid
# , ts
# , person_type
# , name
# , url
# , note
# , email
# , first_name
# , mid_name
# , last_name
# , job_title
# , phd_univ
# , phd_year
# , research_area
# , research_concentration
# , research_focus
# , img_url
# , phone
# , cell_phone
# , office_address
# , department
# , org

# %%
df_src.columns
# Out:
# Index(['name', 'url', 'email', 'first_name', 'mid_name', 'last_name', 'note',
#        'id', 'ts', 'job_title', 'person_type', 'phd_univ', 'phd_year',
#        'research_area', 'research_concentration', 'research_focus', 'img_url',
#        'phone', 'cell_phone', 'office_address', 'department', 'school', 'org'],
#       dtype='object')

# %%
insert_sql = f"""
insert into {table_name} ({col_lst})
select id
    , '{uid}'
    , now()
    , person_type
    , name
    , url
    , note
    , email
    , first_name
    , mid_name
    , last_name
    , job_title
    , phd_univ
    , phd_year
    , research_area
    , research_concentration
    , research_focus
    , img_url
    , phone
    , cell_phone
    , office_address
    , department
    , 'Cornell Univ'
from {src_table_name}
;
"""
print(insert_sql)
# Out:
# insert into g_person (id
# , uid
# , ts
# , person_type
# , name
# , url
# , note
# , email
# , first_name
# , mid_name
# , last_name
# , job_title
# , phd_univ
# , phd_year
# , research_area
# , research_concentration
# , research_focus
# , img_url
# , phone
# , cell_phone
# , office_address
# , department
# , org)
# select id
#     , '0'
#     , now()
#     , person_type
#     , name
#     , url
#     , note
#     , email
#     , first_name
#     , mid_name
#     , last_name
#     , job_title
#     , phd_univ
#     , phd_year
#     , research_area
#     , research_concentration
#     , research_focus
#     , img_url
#     , phone
#     , cell_phone
#     , office_address
#     , department
#     , 'Cornell Univ'
# from t_person
# ;

# %%
with DBConn() as _conn:
    df_test2 = pd.read_sql(f"""
select id
    , '0'
    , now()
    , person_type
    , name
    , url
    , note
    , email
    , first_name
    , mid_name
    , last_name
    , job_title
    , phd_univ
    , phd_year
    , research_area
    , research_concentration
    , research_focus
    , img_url
    , phone
    , cell_phone
    , office_address
    , department
    , 'Cornell Univ'
from t_person
    """, _conn)
df_test2.head(5)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\893381946.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test2 = pd.read_sql(f"""
#                                      id '0'                   now()  \
# 0                     yg534@cornell.edu   0 2023-04-26 02:52:17.095
# 1                     ff227@cornell.edu   0 2023-04-26 02:52:17.095
# 2  409a467e-159e-411e-aedf-206e0ce0d71e   0 2023-04-26 02:52:17.095
# 3  23605352-f553-4289-86fd-e967a3ae693b   0 2023-04-26 02:52:17.095
# 4  edf90ce7-67ff-474d-8b17-47f6e43fa5c2   0 2023-04-26 02:52:17.095
#
#   person_type                 name                                      url  \
# 0     student         Yuchong Geng          https://yuchong-geng.github.io/
# 1     student      Faraz Farahvash    http://networks.ece.cornell.edu/faraz
# 2     faculty  Mohamed Abdelfattah                 https://www.mohsaied.com
# 3     faculty      Jayadev Acharya  https://people.ece.cornell.edu/acharya/
# 4     faculty       Rachit Agarwal     http://www.cs.cornell.edu/~ragarwal/
#
#    note              email first_name mid_name  last_name  \
# 0  None  yg534@cornell.edu    Yuchong     None       Geng
# 1  None  ff227@cornell.edu      Faraz     None  Farahvash
# 2  None                          None     None       None
# 3  None                          None     None       None
# 4  None                          None     None       None
#
#               job_title                        phd_univ phd_year  \
# 0                  None                            None     None
# 1                  None                            None     None
# 2   Assistant Professor                    Univ Toronto     2016
# 3   Assistant Professor       Univ California San Diego     2014
# 4  Associate Professor   Univ Illinois Urbana-Champaign     2013
#
#                                   research_area  \
# 0                             AI Network System
# 1                                          None
# 2     Artificial Intelligence, Machine Learning
# 3  Artificial Intelligence, Theory of Computing
# 4   Systems and Networking, Theory of Computing
#
#                            research_concentration  \
# 0                                            None
# 1                                            None
# 2                         Artificial Intelligence
# 3  Artificial Intelligence, Theory of Computation
# 4                  Systems, Theory of Computation
#
#                                       research_focus  \
# 0                                               None
# 1                                               None
# 2
# 3  Information theory, machine learning, and algo...
# 4  Distributed systems, systems for big data anal...
#
#                                              img_url phone cell_phone  \
# 0                                               None  None       None
# 1                                               None  None       None
# 2  https://www.cs.cornell.edu/sites/default/files...
# 3  https://www.cs.cornell.edu/sites/default/files...
# 4  https://www.cs.cornell.edu/sites/default/files...
#
#   office_address                                         department  \
# 0           None                                               None
# 1           None                                               None
# 2                 Electrical and Computer Engineering, Cornell T...
# 3                 Electrical and Computer Engineering, CS Field ...
# 4                                 Computer Science, CS Field Member
#
#   'Cornell Univ'
# 0   Cornell Univ
# 1   Cornell Univ
# 2   Cornell Univ
# 3   Cornell Univ
# 4   Cornell Univ

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"select * from {table_name};", _conn)
df_test3.head(5)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\199551690.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"select * from {table_name};", _conn)
#                                      id uid                          ts  \
# 0                     yg534@cornell.edu   0  2023-04-25 22:53:12.026-04
# 1                     ff227@cornell.edu   0  2023-04-25 22:53:12.026-04
# 2  409a467e-159e-411e-aedf-206e0ce0d71e   0  2023-04-25 22:53:12.026-04
# 3  23605352-f553-4289-86fd-e967a3ae693b   0  2023-04-25 22:53:12.026-04
# 4  edf90ce7-67ff-474d-8b17-47f6e43fa5c2   0  2023-04-25 22:53:12.026-04
#
#   person_type                 name                                      url  \
# 0     student         Yuchong Geng          https://yuchong-geng.github.io/
# 1     student      Faraz Farahvash    http://networks.ece.cornell.edu/faraz
# 2     faculty  Mohamed Abdelfattah                 https://www.mohsaied.com
# 3     faculty      Jayadev Acharya  https://people.ece.cornell.edu/acharya/
# 4     faculty       Rachit Agarwal     http://www.cs.cornell.edu/~ragarwal/
#
#    note              email first_name mid_name  last_name  \
# 0  None  yg534@cornell.edu    Yuchong     None       Geng
# 1  None  ff227@cornell.edu      Faraz     None  Farahvash
# 2  None                          None     None       None
# 3  None                          None     None       None
# 4  None                          None     None       None
#
#               job_title                        phd_univ phd_year  \
# 0                  None                            None     None
# 1                  None                            None     None
# 2   Assistant Professor                    Univ Toronto     2016
# 3   Assistant Professor       Univ California San Diego     2014
# 4  Associate Professor   Univ Illinois Urbana-Champaign     2013
#
#                                   research_area  \
# 0                             AI Network System
# 1                                          None
# 2     Artificial Intelligence, Machine Learning
# 3  Artificial Intelligence, Theory of Computing
# 4   Systems and Networking, Theory of Computing
#
#                            research_concentration  \
# 0                                            None
# 1                                            None
# 2                         Artificial Intelligence
# 3  Artificial Intelligence, Theory of Computation
# 4                  Systems, Theory of Computation
#
#                                       research_focus  \
# 0                                               None
# 1                                               None
# 2
# 3  Information theory, machine learning, and algo...
# 4  Distributed systems, systems for big data anal...
#
#                                              img_url phone cell_phone  \
# 0                                               None  None       None
# 1                                               None  None       None
# 2  https://www.cs.cornell.edu/sites/default/files...
# 3  https://www.cs.cornell.edu/sites/default/files...
# 4  https://www.cs.cornell.edu/sites/default/files...
#
#   office_address                                         department  \
# 0           None                                               None
# 1           None                                               None
# 2                 Electrical and Computer Engineering, Cornell T...
# 3                 Electrical and Computer Engineering, CS Field ...
# 4                                 Computer Science, CS Field Member
#
#             org
# 0  Cornell Univ
# 1  Cornell Univ
# 2  Cornell Univ
# 3  Cornell Univ
# 4  Cornell Univ

# %% [markdown]
# ## g_entity
#
# ### entity_type = `research_group`

# %%
table_name = "g_entity"
src_table_name = "t_research_group"

# %%
with DBConn() as _conn:
    df_src = pd.read_sql(f"""
        select * from {src_table_name};
    """, _conn)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\298127963.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_src = pd.read_sql(f"""

# %%
df_src.head(5)
# Out:
#                            name  \
# 0       Artificial Intelligence
# 1              Machine Learning
# 2           Theory of Computing
# 3        Systems and Networking
# 4  Computer Architecture & VLSI
#
#                                                  url  note  \
# 0             https://www.cs.cornell.edu/research/ai  None
# 1  https://www.cs.cornell.edu/research/machinelea...  None
# 2         https://www.cs.cornell.edu/research/theory  None
# 3        https://www.cs.cornell.edu/research/systems  None
# 4   https://www.cs.cornell.edu/research/architecture  None
#
#                                      id                          ts
# 0  ccbbb778-7029-4e4b-a166-5ef8cdf21fad  2023-04-23 19:14:58.236-04
# 1  409457be-b415-4413-bdff-7f96d06adbcf  2023-04-23 19:14:58.236-04
# 2  e0a7729b-d4f4-4d90-98b3-04d28a07d64f  2023-04-23 19:14:58.236-04
# 3  0156bf23-5aed-46c1-bcd5-8744499152b1  2023-04-23 19:14:58.236-04
# 4  c09c1373-e525-4057-ae50-d2752cdbc42e  2023-04-23 19:14:58.236-04

# %%
cols_str = """
id
uid
ts
entity_type
name
url
note

"""
cols = [c.strip() for c in cols_str.split("\n") if c.strip()]
cols
# Out:
# ['id', 'uid', 'ts', 'entity_type', 'name', 'url', 'note']

# %%
col_lst = "\n, ".join(cols)
print(col_lst)
# Out:
# id
# , uid
# , ts
# , entity_type
# , name
# , url
# , note

# %%
df_src.columns
# Out:
# Index(['name', 'url', 'note', 'id', 'ts'], dtype='object')

# %%
insert_sql = f"""
insert into {table_name} ({col_lst})
select id
    , '{uid}'
    , now()
    , 'research_group'
    , name
    , url
    , note
from {src_table_name}
;
"""
print(insert_sql)
# Out:
# insert into g_entity (id
# , uid
# , ts
# , entity_type
# , name
# , url
# , note)
# select id
#     , '0'
#     , now()
#     , 'research_group'
#     , name
#     , url
#     , note
# from t_research_group
# ;

# %%
with DBConn() as _conn:
    df_test2 = pd.read_sql(f"""
select id
    , '0'
    , now()
    , 'research_group'
    , name
    , url
    , note
from t_research_group
    """, _conn)
df_test2.head(5)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\3826589568.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test2 = pd.read_sql(f"""
#                                      id '0'                   now()  \
# 0  ccbbb778-7029-4e4b-a166-5ef8cdf21fad   0 2023-04-26 03:06:53.539
# 1  409457be-b415-4413-bdff-7f96d06adbcf   0 2023-04-26 03:06:53.539
# 2  e0a7729b-d4f4-4d90-98b3-04d28a07d64f   0 2023-04-26 03:06:53.539
# 3  0156bf23-5aed-46c1-bcd5-8744499152b1   0 2023-04-26 03:06:53.539
# 4  c09c1373-e525-4057-ae50-d2752cdbc42e   0 2023-04-26 03:06:53.539
#
#   'research_group'                          name  \
# 0   research_group       Artificial Intelligence
# 1   research_group              Machine Learning
# 2   research_group           Theory of Computing
# 3   research_group        Systems and Networking
# 4   research_group  Computer Architecture & VLSI
#
#                                                  url  note
# 0             https://www.cs.cornell.edu/research/ai  None
# 1  https://www.cs.cornell.edu/research/machinelea...  None
# 2         https://www.cs.cornell.edu/research/theory  None
# 3        https://www.cs.cornell.edu/research/systems  None
# 4   https://www.cs.cornell.edu/research/architecture  None

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"select * from {table_name};", _conn)
df_test3
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\1942543153.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"select * from {table_name};", _conn)
#                                       id uid                          ts  \
# 0   ccbbb778-7029-4e4b-a166-5ef8cdf21fad   0  2023-04-25 23:07:14.609-04
# 1   409457be-b415-4413-bdff-7f96d06adbcf   0  2023-04-25 23:07:14.609-04
# 2   e0a7729b-d4f4-4d90-98b3-04d28a07d64f   0  2023-04-25 23:07:14.609-04
# 3   0156bf23-5aed-46c1-bcd5-8744499152b1   0  2023-04-25 23:07:14.609-04
# 4   c09c1373-e525-4057-ae50-d2752cdbc42e   0  2023-04-25 23:07:14.609-04
# 5   8269530c-07b7-410f-a42b-ca680571e24b   0  2023-04-25 23:07:14.609-04
# 6   04b726d5-7b98-4c39-9beb-9401d56bb716   0  2023-04-25 23:07:14.609-04
# 7   62af2b99-c5df-4ba7-abd4-dc9e527e9552   0  2023-04-25 23:07:14.609-04
# 8   1e61712b-fc04-4b51-b42d-7158dfac85fb   0  2023-04-25 23:07:14.609-04
# 9   efdc481a-8f6f-4438-b4be-7bd7264a5496   0  2023-04-25 23:07:14.609-04
# 10  26ee6892-59df-4819-aafb-a953cf70ec63   0  2023-04-25 23:07:14.609-04
# 11  2de9c936-7419-4553-8362-d5953379a76f   0  2023-04-25 23:07:14.609-04
# 12  3f7001ae-23ca-478f-9647-da7fe30ca1da   0  2023-04-25 23:07:14.609-04
# 13  58f6571e-8a1a-4087-b492-190563f9d79d   0  2023-04-25 23:07:14.609-04
# 14  e133e068-4e94-488a-9b53-045483ae56fa   0  2023-04-25 23:07:14.609-04
# 15  b14f5cc7-f44c-493c-a649-0cbc09257c02   0  2023-04-25 23:07:14.609-04
#
#        entity_type                          name  \
# 0   research_group       Artificial Intelligence
# 1   research_group              Machine Learning
# 2   research_group           Theory of Computing
# 3   research_group        Systems and Networking
# 4   research_group  Computer Architecture & VLSI
# 5   research_group             Human Interaction
# 6   research_group                      Graphics
# 7   research_group                        Vision
# 8   research_group                      Robotics
# 9   research_group          Scientific Computing
# 10  research_group                      Security
# 11  research_group         Programming Languages
# 12  research_group              Database Systems
# 13  research_group         Computational Biology
# 14  research_group          Software Engineering
# 15  research_group   Natural Language Processing
#
#                                                   url  note
# 0              https://www.cs.cornell.edu/research/ai  None
# 1   https://www.cs.cornell.edu/research/machinelea...  None
# 2          https://www.cs.cornell.edu/research/theory  None
# 3         https://www.cs.cornell.edu/research/systems  None
# 4    https://www.cs.cornell.edu/research/architecture  None
# 5   https://www.cs.cornell.edu/research/humaninter...  None
# 6        https://www.cs.cornell.edu/research/graphics  None
# 7          https://www.cs.cornell.edu/research/vision  None
# 8                       https://robotics.cornell.edu/  None
# 9        https://www.cs.cornell.edu/research/scientif  None
# 10       https://www.cs.cornell.edu/research/security  None
# 11           https://www.cs.cornell.edu/research/lang  None
# 12    https://www.cs.cornell.edu/research/datasystems  None
# 13        https://www.cs.cornell.edu/research/compbio  None
# 14  https://www.cs.cornell.edu/research/software-e...  None
# 15  https://www.cs.cornell.edu/research/natural-la...  None

# %% [markdown]
# ### entity_type = `org`

# %%
with DBConn() as _conn:
    df_tmp = pd.read_sql(f"""
select uuid()
    , '0'
    , now()
    , 'org'
    , 'Cornell Univ'
    , 'https://www.cornell.edu/'
    , Null
;
    """, _conn)
df_tmp
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\3913033656.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_tmp = pd.read_sql(f"""
#                                  uuid() '0'                   now() 'org'  \
# 0  06e2ea82-64ec-47bb-b988-18e71ddb470a   0 2023-04-26 03:14:16.887   org
#
#   'Cornell Univ' 'https://www.cornell.edu/'  NULL
# 0   Cornell Univ   https://www.cornell.edu/  None

# %%
insert_sql = f"""
insert into g_entity (id
, uid
, ts
, entity_type
, name
, url
, note)
select uuid()
    , '0'
    , now()
    , 'org'
    , 'Cornell Univ'
    , 'https://www.cornell.edu/'
    , Null
;
;
"""

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"select * from g_entity where entity_type='org';", _conn)
df_test3
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\4066688269.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"select * from g_entity where entity_type='org';", _conn)
#                                      id uid                          ts  \
# 0  347d84f3-cc06-4b04-b8be-95bfb573c3d1   0  2023-04-25 23:14:54.295-04
#
#   entity_type          name                       url  note
# 0         org  Cornell Univ  https://www.cornell.edu/  None

# %% [markdown]
# ## g_relation

# %% [markdown]
# ### rel_type = `person-work`

# %%
table_name = "g_relation"
src_table_name = "t_person_work"

# %%
with DBConn() as _conn:
    df_src = pd.read_sql(f"""
        select * from {src_table_name};
    """, _conn)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\298127963.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_src = pd.read_sql(f"""

# %%
df_src
# Out:
#                                      id                          ts  ref_type  \
# 0             atang/pub/22/ICML2022.pdf         2023-04-16 10:01:01  t_person
# 1         atang/pub/21/NeurIPS-2021.pdf         2023-04-16 10:01:02  t_person
# 2  fff7e2d9-7f5c-47c0-aa37-6f5f4b48757b  2023-04-23 13:08:54.664621  t_person
#
#                                 ref_key ref_type_2  \
# 0  http://people.ece.cornell.edu/atang/     t_work
# 1  http://people.ece.cornell.edu/atang/     t_work
# 2  http://people.ece.cornell.edu/atang/     t_work
#
#                               ref_key_2
# 0             atang/pub/22/ICML2022.pdf
# 1         atang/pub/21/NeurIPS-2021.pdf
# 2  b62cf974-c5e4-494a-a29c-e34576bb1ec2

# %%
cols_str = """
id
uid
ts
rel_type
ref_key
ref_val
ref_key_sub
ref_val_sub

"""
cols = [c.strip() for c in cols_str.split("\n") if c.strip()]
cols
# Out:
# ['id',
#  'uid',
#  'ts',
#  'rel_type',
#  'ref_key',
#  'ref_val',
#  'ref_key_sub',
#  'ref_val_sub']

# %%
col_lst = "\n, ".join(cols)
print(col_lst)
# Out:
# id
# , uid
# , ts
# , rel_type
# , ref_key
# , ref_val
# , ref_key_sub
# , ref_val_sub

# %%
df_src.columns
# Out:
# Index(['id', 'ts', 'ref_type', 'ref_key', 'ref_type_2', 'ref_key_2'], dtype='object')

# %%
insert_sql = f"""
insert into {table_name} ({col_lst})
select id
    , '{uid}'
    , ts
    , 'person-work'
, 'g_person#url'
, ref_key
, 'g_work#id'
, ref_key_2
from {src_table_name}
;
"""
print(insert_sql)
# Out:
# insert into g_relation (id
# , uid
# , ts
# , rel_type
# , ref_key
# , ref_val
# , ref_key_sub
# , ref_val_sub)
# select id
#     , '0'
#     , ts
#     , 'person-work'
# , 'g_person#url'
# , ref_key
# , 'g_work#id'
# , ref_key_2
# from t_person_work
# ;

# %%
with DBConn() as _conn:
    df_test2 = pd.read_sql(f"""
select id
    , '0'
    , ts
    , 'person-work'
, 'g_person#url'
, ref_key
, 'g_work#id'
, ref_key_2
from t_person_work
    """, _conn)
df_test2
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\765401097.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test2 = pd.read_sql(f"""
#                                      id '0'                          ts  \
# 0             atang/pub/22/ICML2022.pdf   0         2023-04-16 10:01:01
# 1         atang/pub/21/NeurIPS-2021.pdf   0         2023-04-16 10:01:02
# 2  fff7e2d9-7f5c-47c0-aa37-6f5f4b48757b   0  2023-04-23 13:08:54.664621
#
#   'person-work' 'g_person#url'                               ref_key  \
# 0   person-work   g_person#url  http://people.ece.cornell.edu/atang/
# 1   person-work   g_person#url  http://people.ece.cornell.edu/atang/
# 2   person-work   g_person#url  http://people.ece.cornell.edu/atang/
#
#   'g_work#id'                             ref_key_2
# 0   g_work#id             atang/pub/22/ICML2022.pdf
# 1   g_work#id         atang/pub/21/NeurIPS-2021.pdf
# 2   g_work#id  b62cf974-c5e4-494a-a29c-e34576bb1ec2

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"select * from {table_name} where rel_type='person-work';", _conn)
df_test3
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\2382609479.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"select * from {table_name} where rel_type='person-work';", _conn)
#                                      id uid                          ts  \
# 0             atang/pub/22/ICML2022.pdf   0         2023-04-16 10:01:01
# 1         atang/pub/21/NeurIPS-2021.pdf   0         2023-04-16 10:01:02
# 2  fff7e2d9-7f5c-47c0-aa37-6f5f4b48757b   0  2023-04-23 13:08:54.664621
#
#       rel_type       ref_key                               ref_val  \
# 0  person-work  g_person#url  http://people.ece.cornell.edu/atang/
# 1  person-work  g_person#url  http://people.ece.cornell.edu/atang/
# 2  person-work  g_person#url  http://people.ece.cornell.edu/atang/
#
#   ref_key_sub                           ref_val_sub
# 0   g_work#id             atang/pub/22/ICML2022.pdf
# 1   g_work#id         atang/pub/21/NeurIPS-2021.pdf
# 2   g_work#id  b62cf974-c5e4-494a-a29c-e34576bb1ec2

# %% [markdown]
# ### rel_type = `team-person`
#
# default team by faculty

# %%
table_name = "g_relation"
src_table_name = "t_person_team"

# %%
with DBConn() as _conn:
    df_src = pd.read_sql(f"""
        select * from {src_table_name};
    """, _conn)
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\298127963.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_src = pd.read_sql(f"""

# %%
df_src
# Out:
#                                                  id                   ts  \
# 0   t_person # http://people.ece.cornell.edu/atang/  2023-04-16 10:01:01
# 1        t_person # https://yuchong-geng.github.io/  2023-04-16 10:01:01
# 2  t_person # http://networks.ece.cornell.edu/faraz  2023-04-16 10:01:01
#
#   ref_type                           ref_key ref_type_2  \
# 0   t_team  http://networks.ece.cornell.edu/   t_person
# 1   t_team  http://networks.ece.cornell.edu/   t_person
# 2   t_team  http://networks.ece.cornell.edu/   t_person
#
#                                ref_key_2
# 0   http://people.ece.cornell.edu/atang/
# 1        https://yuchong-geng.github.io/
# 2  http://networks.ece.cornell.edu/faraz

# %%
cols_str = """
id
uid
ts
rel_type
ref_key
ref_val
ref_key_sub
ref_val_sub

"""
cols = [c.strip() for c in cols_str.split("\n") if c.strip()]
cols
# Out:
# ['id',
#  'uid',
#  'ts',
#  'rel_type',
#  'ref_key',
#  'ref_val',
#  'ref_key_sub',
#  'ref_val_sub']

# %%
col_lst = "\n, ".join(cols)
print(col_lst)
# Out:
# id
# , uid
# , ts
# , rel_type
# , ref_key
# , ref_val
# , ref_key_sub
# , ref_val_sub

# %%
df_src.columns
# Out:
# Index(['id', 'ts', 'ref_type', 'ref_key', 'ref_type_2', 'ref_key_2'], dtype='object')

# %%
insert_sql = f"""
insert into {table_name} ({col_lst})
select id
    , '{uid}'
    , ts
    , 'team-person'
, 'g_person#url'
, ref_key
, 'g_person#url'
, ref_key_2
from {src_table_name}
;
"""
print(insert_sql)
# Out:
# insert into g_relation (id
# , uid
# , ts
# , rel_type
# , ref_key
# , ref_val
# , ref_key_sub
# , ref_val_sub)
# select id
#     , '0'
#     , ts
#     , 'team-person'
# , 'g_person#url'
# , ref_key
# , 'g_person#url'
# , ref_key_2
# from t_person_team
# ;

# %%
with DBConn() as _conn:
    df_test2 = pd.read_sql(f"""
select id
    , '0'
    , ts
    , 'team-person'
, 'g_person#url'
, ref_key
, 'g_person#url'
, ref_key_2
from t_person_team
    """, _conn)
df_test2
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\2266003013.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test2 = pd.read_sql(f"""
#                                                  id '0'                   ts  \
# 0   t_person # http://people.ece.cornell.edu/atang/   0  2023-04-16 10:01:01
# 1        t_person # https://yuchong-geng.github.io/   0  2023-04-16 10:01:01
# 2  t_person # http://networks.ece.cornell.edu/faraz   0  2023-04-16 10:01:01
#
#   'team-person' 'g_person#url'                           ref_key  \
# 0   team-person   g_person#url  http://networks.ece.cornell.edu/
# 1   team-person   g_person#url  http://networks.ece.cornell.edu/
# 2   team-person   g_person#url  http://networks.ece.cornell.edu/
#
#   'g_person#url'                              ref_key_2
# 0   g_person#url   http://people.ece.cornell.edu/atang/
# 1   g_person#url        https://yuchong-geng.github.io/
# 2   g_person#url  http://networks.ece.cornell.edu/faraz

# %%
# insert
with DBConn() as _conn:
    _conn.execute(insert_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"select * from {table_name} where rel_type='team-person';", _conn)
df_test3
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\2937123922.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"select * from {table_name} where rel_type='team-person';", _conn)
#                                                  id uid                   ts  \
# 0   t_person # http://people.ece.cornell.edu/atang/   0  2023-04-16 10:01:01
# 1        t_person # https://yuchong-geng.github.io/   0  2023-04-16 10:01:01
# 2  t_person # http://networks.ece.cornell.edu/faraz   0  2023-04-16 10:01:01
#
#       rel_type       ref_key                           ref_val   ref_key_sub  \
# 0  team-person  g_person#url  http://networks.ece.cornell.edu/  g_person#url
# 1  team-person  g_person#url  http://networks.ece.cornell.edu/  g_person#url
# 2  team-person  g_person#url  http://networks.ece.cornell.edu/  g_person#url
#
#                              ref_val_sub
# 0   http://people.ece.cornell.edu/atang/
# 1        https://yuchong-geng.github.io/
# 2  http://networks.ece.cornell.edu/faraz

# %%
# data fix

update_sql = f"""
update {table_name}
set 
    ref_val = 'http://people.ece.cornell.edu/atang/'
where rel_type='team-person';
"""

with DBConn() as _conn:
    _conn.execute(update_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"""
        select * from {table_name} 
        where rel_type='team-person'
        and ref_val = ref_val_sub;
        """, _conn)
df_test3
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\2347093513.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"""
# Empty DataFrame
# Columns: [id, uid, ts, rel_type, ref_key, ref_val, ref_key_sub, ref_val_sub]
# Index: []

# %%
# data fix

delete_sql = f"""
delete from {table_name} 
where rel_type='team-person'
and ref_val = ref_val_sub;
"""

with DBConn() as _conn:
    _conn.execute(delete_sql)
    _conn.commit()

# %%
# query
with DBConn() as _conn:
    df_test3 = pd.read_sql(f"select * from {table_name} where rel_type='team-person';", _conn)
df_test3
# Out:
# C:\Users\p2p2l\AppData\Local\Temp\ipykernel_17572\2937123922.py:3: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_test3 = pd.read_sql(f"select * from {table_name} where rel_type='team-person';", _conn)
#                                                  id uid                   ts  \
# 0        t_person # https://yuchong-geng.github.io/   0  2023-04-16 10:01:01
# 1  t_person # http://networks.ece.cornell.edu/faraz   0  2023-04-16 10:01:01
#
#       rel_type       ref_key                               ref_val  \
# 0  team-person  g_person#url  http://people.ece.cornell.edu/atang/
# 1  team-person  g_person#url  http://people.ece.cornell.edu/atang/
#
#     ref_key_sub                            ref_val_sub
# 0  g_person#url        https://yuchong-geng.github.io/
# 1  g_person#url  http://networks.ece.cornell.edu/faraz
